# %% [markdown]
# <a href="https://colab.research.google.com/github/stariq20/practical-python/blob/master/Testing_LLMs.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#!pip install transformers

# %%
#!nvidia-smi

# %%
#!pip install huggingface_hub

# %%
# Set the environment variable HUGGINGFACE_TOKEN
#import os
#import getpass
#os.environ["HUGGINGFACE_TOKEN"]=getpass.getpass()

# %%
#hugging_key=os.getenv("HUGGINGFACE_TOKEN")

# %% [markdown]
# ##Bio-Bert Classifier: WORKING BUT ONLY A CLASSIFIER

# %%
from transformers import AutoTokenizer, AutoModelForSequenceClassification
import torch

# Load pre-trained BioBERT model and tokenizer
tokenizer = AutoTokenizer.from_pretrained("dmis-lab/biobert-v1.1")
model = AutoModelForSequenceClassification.from_pretrained("dmis-lab/biobert-v1.1", num_labels=2)

# Example input text
text = '''Patient notes: INDICATION:  ___ year old man with congenital hepatic fibrosis and portal
hypertension  // TIPS revision/thrombectomy - seen by Dr. ___ ___

COMPARISON:  CT of the abdomen pelvis dated ___

TECHNIQUE:  OPERATORS: Dr. ___ Dr. ___ Interventional
___ and Dr. ___ fellow performed the
procedure.  The attending(s) personally supervised the trainee during any key
components of the procedure where applicable and reviewed and agrees with the
findings as reported below.
ANESTHESIA: Moderate sedation was provided by administrating divided doses of
300mcg of fentanyl and 7.5 mg of midazolam throughout the total intra-service
time of 7 hours and 58 minutes during which the patient's hemodynamic
parameters were continuously monitored by an independent trained radiology
nurse.  1% lidocaine was injected in the skin and subcutaneous tissues
overlying the access site.
MEDICATIONS: 4 mg intravenous tPA delivered through TIPS sheath
CONTRAST: 235 ml of Optiray contrast
FLUOROSCOPY TIME AND DOSE:  184.6 minutes, 2710 mGy

PROCEDURE:
1. Right internal jugular venous access using ultrasound.
2. Pre-procedure right atrial pressure measurements
3. Percutaneous transhepatic access into the TIPS stent.
4. Retrograde snaring of the percutaneous access into the right IJ
5. Trans jugular approach direct access into the upper portion of the
pre-existing TIPS stent
6. Cone beam CT of the TIPS and portal venous system prior to placement of the
new direct TIPS into the pre-existing TIPS
7. Placement of a 10 mm x 6 cm + 2 cm Viatorr partially-covered stent
8. Post-stenting balloon angioplasty of the TIPS shunt and portal vein with a
10 mm balloon.
9. Post-stenting portal venograms.
10. Extension of the cranial portion of the new portosystemic shunt (DIPS)
using a 12 x 40 x 75 lumenneX stent
___. Aspiration thrombectomy of the main portal vein and TIPS stent using a
penumbra device- CAT 8 system
12. TPA administration via the TIPS sheath
13. Gel-Foam pledget tract embolization of the percutaneous transhepatic TIPS
access
14. Placement of a tPA infusion catheter into the portal vein/SMV for
resistant clot
15. A double-lumen PICC was placed via patent right basilic vein


PROCEDURE DETAILS: Following the discussion of the risks, benefits and
alternatives to the procedure, written informed consent was obtained from the
patient. The patient was then brought to the angiography suite and placed
supine on the exam table. A pre-procedure time-out was performed per ___
protocol.  The right neck and abdomen were prepped and draped in the usual
sterile fashion.

Under continuous ultrasound guidance, the patent right internal jugular vein
was compressible and accessed using a micropuncture needle.  Images of
ultrasound access were stored on PACS. Subsequently a Nitinol wire was passed
into the right atrium using fluoroscopic guidance. A small incision was made
at the needle entry site. The needle was exchanged for a micropuncture sheath.
The Nitinol wire was removed and a ___ wire was advanced distally into
the IVC.

The micropuncture sheath was then removed and a 10 ___ sheath was advanced
over the wire into the inferior vena cava.  Right atrium pressure measurements
were obtained.  Multiple 5 ___ catheters including an MPA, SOS, C2 modified
___ catheters were used to attempt access into the existing TIPS.  These were
unsuccessful initially.  Access into the existing TIPS was then obtained using
a TIPS set.  The TIPS cannula device was inserted over the Amplatz wire and
the wire was exchanged for a long Chiba needle. The needle was then advanced
through liver parenchyma.  Upon access into the existing TIPS, a J-tip wire
was introduced into the catheter to pass into the portal vein via the TIPS,
with care taken not to traverse the interstices of the portal end of the TIPS.
A straight flush catheter was advanced over the wire and a contrast enhanced
portal venogram was performed.  Once access had been achieved into the TIPS,
the direct TIPS tract was angioplasties up to 10 mm.

Percutaneous transhepatic TIPS access was achieved into the mid portion of the
TIPS using a 20 gauge Chiba needle.  Stiff 018 v 18 wire was then advanced
into the existing TIPS.  This was snared through the direct right IJV approach
TIPS access sheath into the right IJ for through and through access.  Once
access was established into the portal system, this was converted into an 035
system using several exchanges involving Rubicon catheters and multiple 035
wires including stiff glide, glide and Amplatz wires.

Attempts at retrograde wire access to the cranial portion of the occluded TIPS
via the percutaneous transhepatic access were unsuccessful after multiple
attempts.  A cone beam CT was then performed.
 Rotational cone-beam CT angiography was performed to help delineate the
anatomy.  Multiplanar CT images were reconstructed and 3D volume-rendered
images of the venous anatomy required post-processing on an independent
workstation under direct physician ___.  These images were used in the
interpretation, decision making for intervention and reporting of this
procedure.
Next, through the new tranjugular direct TIPS access, the TIPS itself and the
main portal vein were treated with 10mm plasty using high-pressure balloons.
Post plasty venography was performed which demonstrated clot burden in the
main portal vein in TIPS with little flow through the TIPS itself.  Further
balloon plasty was performed at several locations, as documented.  Once
appropriate opacification of the main portal vein was confirmed, a new  10 x 6
+ 2 cm Viatorr partially-covered stent was advanced into appropriate position
and deployed. Following stent deployment, the stent was dilated using a 10 mm
balloon.

Post stenting venography demonstrated significant clot burden and irregular
appearance of the superior portion of the stent.  Another cone beam CT was
therefore performed to delineate anatomy and interventional planning.

Rotational cone-beam CT angiography was performed to help delineate the
anatomy.  Multiplanar CT images were reconstructed and 3D volume-rendered
images of the venous anatomy required post-processing on an independent
workstation under direct physician ___.  These images were used in the
interpretation, decision making for intervention and reporting of this
procedure.
A decision was made to line the cranial aspect of the new direct TIPS with and
uncovered 12 x 40 x 75 luminnex stent.  This was deployed in the appropriate
position with care being taken to avoid stent migration.  Post repeat stenting
balloon plasty was performed up to 12 mm.  This included portions of the
direct TIPS, the pre-existing TIPS as well as the main portal vein.  Post
plasty injections demonstrated still significant clot burden within the main
portal vein and tributaries.  A decision was made to apply aspiration
thrombectomy using a penumbra device-CAT 8.

Post aspiration thrombectomy venography demonstrated improved patency of the
main portal vein on post venography with minimal flow through the TIPS.  The
diagnostic venography was medically necessary given the absence of recent
catheter venography. TPA was administered into the TIPS stent via the TIPS
sheath.  However, the TIPS itself remained potentially thrombosed.  It was
therefore decided to leave a ___ thrombolysis infusion
catheter in place overnight for tPA administration.
The sheath was then secured to the skin at the right neck site using an 0 silk
suture.  The infusion catheter was secured to the outer sheath.  A sterile
dressing was applied.
The percutaneous transhepatic access was embolized using Gelfoam pledgets.  A
sterile dressing was applied. Limited US did not demonstrate any ___
fluid post tract embolization.
Next, the right arm was prepped and draped in the usual sterile fashion.
Under ultrasound guidance, the patent basilic vein was accessed.  A
double-lumen PICC was inserted with the tip of the PICC in the SVC.  The line
was flushed, secured to the skin and a sterile dressing was applied.

The patient tolerated the procedure well.  There were no immediate
post-procedure complications. The patient was transferred to the ICU in stable
condition.

FINDINGS:


1. Pre-TIPS right atrial pressure of 20 mmHg.
2. Occluded indwelling TIPS with inability to get access via transjugular
approach initially
3. Successful percutaneous access the occluded TIPS using a 20 gauge Chiba
needle.  An 018 wire was then snared superiorly through the right IJ approach
sheath
4. Direct TIPS access venography demonstrated significant clot burden within
the main portal vein.
5. Cone beam CT demonstrated occluded TIPS with passage of access wires within
the stent without evidence for crossing interstices of the portal end of the
TIPS.
6. Post new TIPS extension right atrial pressure of 20 and portal pressure of
45 resulting in portosystemic gradient of 25 mmHg.
7. Successful balloon angioplasty of the main portal vein.  Angioplasty of the
indwelling TIPS and TIPS was also performed up to 10 mm.
8.
9. Post plasty venography demonstrated large decompressive left upper quadrant
gastric varices and other upper abdominal collateral venous channels.  There
was significant thrombosis of the main portal vein.
10. Post plasty venography demonstrated significant clot burden within the
main portal vein and TIPS.  Aspiration thrombectomy of the main portal vein
and TIPS was performed using the penumbra aspiration device with significant
debulking of clot post aspiration thrombectomy.
 11. Post plasty cone beam CT demonstrated an irregular narrowing at the
cranial portion of the new portosystemic shunt.  This was successfully lined
using an  uncovered 12 x 40 x 75 luminnex stent
___. Post plasty and application of the aspiration catheter venography
demonstrated patent main portal vein.  The TIPS was occluded at the end of the
procedure.
13. A 4 ___ ___ lysis catheter was placed in main portal vein
for tPA infusion
14. Gel-Foam pledget tract embolization of the percutaneous transhepatic TIPS
access.  Post tract embolization focused ultrasound demonstrated no evidence
of local hematoma.
15. A double-lumen PICC was placed via patent right basilic vein with tip in
the distal SVC.

IMPRESSION:

Successful right internal jugular access with direct transjugular intrahepatic
portosystemic shunt revision with extension of the TIPS cranially.

New direct TIPS aspiration thrombectomy.

Thrombolysis catheter placement through the right IJ sheath for overnight
thrombolysis


Insurance policy: CT Maxillofacial without contrast (CPT® 70486) or CT Sinus, limited without contrast
(CPT® 76380) is indicated in those with suspicion of Upper Airway Cough Syndrome
(UACS) in the following:4,5,6
o Clinical criteria for chronic rhinosinusitis (CRS) or acute/recurrent rhinosinusitis
are met, as per Sinus and Facial Imaging (HD 29.1) ; OR ALL of the following:
 At least a one week trial of daily antihistamine/decongestant
 Initial evaluation with a chest x-ray and/or CT Chest after the current episode
of cough started or changed
 All medications known to cause cough have been discontinued
Question: Is this service considered medically necessary for the patient? If not, what additional information could be included for the service to be considered medically necessary?
'''

# Tokenize the input text
inputs = tokenizer(text, return_tensors="pt", truncation=True, max_length=512)

# Perform inference
with torch.no_grad():
    outputs = model(**inputs)

# Get the predicted class
logits = outputs.logits
predicted_class_id = torch.argmax(logits).item()

# Map the predicted class to a human-readable label
labels = ["Not Medically Necessary", "Medically Necessary"]
predicted_label = labels[predicted_class_id]

print(f"Predicted label: {predicted_label}")
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:89: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# tokenizer_config.json:   0%|          | 0.00/49.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/462 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/213k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/433M [00:00<?, ?B/s]
# ...

# %% [markdown]
# ##Bio-GPT: WORKING NOT USEFUL RESPONSE

# %%
# !pip install -U sacremoses
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 897.5/897.5 kB 3.5 MB/s eta 0:00:00
# ...

# %%
from transformers import AutoTokenizer, BioGptForCausalLM
import torch

# Load the pre-trained BioGPT model and tokenizer
tokenizer = AutoTokenizer.from_pretrained("microsoft/biogpt")
model = BioGptForCausalLM.from_pretrained("microsoft/biogpt")

# Example input text
text = '''Patient notes: INDICATION:  ___ year old man with congenital hepatic fibrosis and portal
hypertension  // TIPS revision/thrombectomy - seen by Dr. ___ ___

COMPARISON:  CT of the abdomen pelvis dated ___

TECHNIQUE:  OPERATORS: Dr. ___ Dr. ___ Interventional
___ and Dr. ___ fellow performed the
procedure.  The attending(s) personally supervised the trainee during any key
components of the procedure where applicable and reviewed and agrees with the
findings as reported below.
ANESTHESIA: Moderate sedation was provided by administrating divided doses of
300mcg of fentanyl and 7.5 mg of midazolam throughout the total intra-service
time of 7 hours and 58 minutes during which the patient's hemodynamic
parameters were continuously monitored by an independent trained radiology
nurse.  1% lidocaine was injected in the skin and subcutaneous tissues
overlying the access site.
MEDICATIONS: 4 mg intravenous tPA delivered through TIPS sheath
CONTRAST: 235 ml of Optiray contrast
FLUOROSCOPY TIME AND DOSE:  184.6 minutes, 2710 mGy

PROCEDURE:
1. Right internal jugular venous access using ultrasound.
2. Pre-procedure right atrial pressure measurements
3. Percutaneous transhepatic access into the TIPS stent.
4. Retrograde snaring of the percutaneous access into the right IJ
5. Trans jugular approach direct access into the upper portion of the
pre-existing TIPS stent
6. Cone beam CT of the TIPS and portal venous system prior to placement of the
new direct TIPS into the pre-existing TIPS
7. Placement of a 10 mm x 6 cm + 2 cm Viatorr partially-covered stent
8. Post-stenting balloon angioplasty of the TIPS shunt and portal vein with a
10 mm balloon.
9. Post-stenting portal venograms.
10. Extension of the cranial portion of the new portosystemic shunt (DIPS)
using a 12 x 40 x 75 lumenneX stent
___. Aspiration thrombectomy of the main portal vein and TIPS stent using a
penumbra device- CAT 8 system
12. TPA administration via the TIPS sheath
13. Gel-Foam pledget tract embolization of the percutaneous transhepatic TIPS
access
14. Placement of a tPA infusion catheter into the portal vein/SMV for
resistant clot
15. A double-lumen PICC was placed via patent right basilic vein


PROCEDURE DETAILS: Following the discussion of the risks, benefits and
alternatives to the procedure, written informed consent was obtained from the
patient. The patient was then brought to the angiography suite and placed
supine on the exam table. A pre-procedure time-out was performed per ___
protocol.  The right neck and abdomen were prepped and draped in the usual
sterile fashion.

Under continuous ultrasound guidance, the patent right internal jugular vein
was compressible and accessed using a micropuncture needle.  Images of
ultrasound access were stored on PACS. Subsequently a Nitinol wire was passed
into the right atrium using fluoroscopic guidance. A small incision was made
at the needle entry site. The needle was exchanged for a micropuncture sheath.
The Nitinol wire was removed and a ___ wire was advanced distally into
the IVC.

The micropuncture sheath was then removed and a 10 ___ sheath was advanced
over the wire into the inferior vena cava.  Right atrium pressure measurements
were obtained.  Multiple 5 ___ catheters including an MPA, SOS, C2 modified
___ catheters were used to attempt access into the existing TIPS.  These were
unsuccessful initially.  Access into the existing TIPS was then obtained using
a TIPS set.  The TIPS cannula device was inserted over the Amplatz wire and
the wire was exchanged for a long Chiba needle. The needle was then advanced
through liver parenchyma.  Upon access into the existing TIPS, a J-tip wire
was introduced into the catheter to pass into the portal vein via the TIPS,
with care taken not to traverse the interstices of the portal end of the TIPS.
A straight flush catheter was advanced over the wire and a contrast enhanced
portal venogram was performed.  Once access had been achieved into the TIPS,
the direct TIPS tract was angioplasties up to 10 mm.

Percutaneous transhepatic TIPS access was achieved into the mid portion of the
TIPS using a 20 gauge Chiba needle.  Stiff 018 v 18 wire was then advanced
into the existing TIPS.  This was snared through the direct right IJV approach
TIPS access sheath into the right IJ for through and through access.  Once
access was established into the portal system, this was converted into an 035
system using several exchanges involving Rubicon catheters and multiple 035
wires including stiff glide, glide and Amplatz wires.

Attempts at retrograde wire access to the cranial portion of the occluded TIPS
via the percutaneous transhepatic access were unsuccessful after multiple
attempts.  A cone beam CT was then performed.
 Rotational cone-beam CT angiography was performed to help delineate the
anatomy.  Multiplanar CT images were reconstructed and 3D volume-rendered
images of the venous anatomy required post-processing on an independent
workstation under direct physician ___.  These images were used in the
interpretation, decision making for intervention and reporting of this
procedure.
Next, through the new tranjugular direct TIPS access, the TIPS itself and the
main portal vein were treated with 10mm plasty using high-pressure balloons.
Post plasty venography was performed which demonstrated clot burden in the
main portal vein in TIPS with little flow through the TIPS itself.  Further
balloon plasty was performed at several locations, as documented.  Once
appropriate opacification of the main portal vein was confirmed, a new  10 x 6
+ 2 cm Viatorr partially-covered stent was advanced into appropriate position
and deployed. Following stent deployment, the stent was dilated using a 10 mm
balloon.

Post stenting venography demonstrated significant clot burden and irregular
appearance of the superior portion of the stent.  Another cone beam CT was
therefore performed to delineate anatomy and interventional planning.

Rotational cone-beam CT angiography was performed to help delineate the
anatomy.  Multiplanar CT images were reconstructed and 3D volume-rendered
images of the venous anatomy required post-processing on an independent
workstation under direct physician ___.  These images were used in the
interpretation, decision making for intervention and reporting of this
procedure.
A decision was made to line the cranial aspect of the new direct TIPS with and
uncovered 12 x 40 x 75 luminnex stent.  This was deployed in the appropriate
position with care being taken to avoid stent migration.  Post repeat stenting
balloon plasty was performed up to 12 mm.  This included portions of the
direct TIPS, the pre-existing TIPS as well as the main portal vein.  Post
plasty injections demonstrated still significant clot burden within the main
portal vein and tributaries.  A decision was made to apply aspiration
thrombectomy using a penumbra device-CAT 8.

Post aspiration thrombectomy venography demonstrated improved patency of the
main portal vein on post venography with minimal flow through the TIPS.  The
diagnostic venography was medically necessary given the absence of recent
catheter venography. TPA was administered into the TIPS stent via the TIPS
sheath.  However, the TIPS itself remained potentially thrombosed.  It was
therefore decided to leave a ___ thrombolysis infusion
catheter in place overnight for tPA administration.
The sheath was then secured to the skin at the right neck site using an 0 silk
suture.  The infusion catheter was secured to the outer sheath.  A sterile
dressing was applied.
The percutaneous transhepatic access was embolized using Gelfoam pledgets.  A
sterile dressing was applied. Limited US did not demonstrate any ___
fluid post tract embolization.
Next, the right arm was prepped and draped in the usual sterile fashion.
Under ultrasound guidance, the patent basilic vein was accessed.  A
double-lumen PICC was inserted with the tip of the PICC in the SVC.  The line
was flushed, secured to the skin and a sterile dressing was applied.

The patient tolerated the procedure well.  There were no immediate
post-procedure complications. The patient was transferred to the ICU in stable
condition.

FINDINGS:


1. Pre-TIPS right atrial pressure of 20 mmHg.
2. Occluded indwelling TIPS with inability to get access via transjugular
approach initially
3. Successful percutaneous access the occluded TIPS using a 20 gauge Chiba
needle.  An 018 wire was then snared superiorly through the right IJ approach
sheath
4. Direct TIPS access venography demonstrated significant clot burden within
the main portal vein.
5. Cone beam CT demonstrated occluded TIPS with passage of access wires within
the stent without evidence for crossing interstices of the portal end of the
TIPS.
6. Post new TIPS extension right atrial pressure of 20 and portal pressure of
45 resulting in portosystemic gradient of 25 mmHg.
7. Successful balloon angioplasty of the main portal vein.  Angioplasty of the
indwelling TIPS and TIPS was also performed up to 10 mm.
8.
9. Post plasty venography demonstrated large decompressive left upper quadrant
gastric varices and other upper abdominal collateral venous channels.  There
was significant thrombosis of the main portal vein.
10. Post plasty venography demonstrated significant clot burden within the
main portal vein and TIPS.  Aspiration thrombectomy of the main portal vein
and TIPS was performed using the penumbra aspiration device with significant
debulking of clot post aspiration thrombectomy.
 11. Post plasty cone beam CT demonstrated an irregular narrowing at the
cranial portion of the new portosystemic shunt.  This was successfully lined
using an  uncovered 12 x 40 x 75 luminnex stent
___. Post plasty and application of the aspiration catheter venography
demonstrated patent main portal vein.  The TIPS was occluded at the end of the
procedure.
13. A 4 ___ ___ lysis catheter was placed in main portal vein
for tPA infusion
14. Gel-Foam pledget tract embolization of the percutaneous transhepatic TIPS
access.  Post tract embolization focused ultrasound demonstrated no evidence
of local hematoma.
15. A double-lumen PICC was placed via patent right basilic vein with tip in
the distal SVC.

IMPRESSION:

Successful right internal jugular access with direct transjugular intrahepatic
portosystemic shunt revision with extension of the TIPS cranially.

New direct TIPS aspiration thrombectomy.

Thrombolysis catheter placement through the right IJ sheath for overnight
thrombolysis


Insurance policy: CT Maxillofacial without contrast (CPT® 70486) or CT Sinus, limited without contrast
(CPT® 76380) is indicated in those with suspicion of Upper Airway Cough Syndrome
(UACS) in the following:4,5,6
o Clinical criteria for chronic rhinosinusitis (CRS) or acute/recurrent rhinosinusitis
are met, as per Sinus and Facial Imaging (HD 29.1) ; OR ALL of the following:
 At least a one week trial of daily antihistamine/decongestant
 Initial evaluation with a chest x-ray and/or CT Chest after the current episode
of cough started or changed
 All medications known to cause cough have been discontinued
Question: Is this service considered medically necessary for the patient? If not, what additional information could be included for the service to be considered medically necessary?
'''

# Tokenize the input text
inputs = tokenizer(text, return_tensors="pt", truncation=True, max_length=512)

# Generate text
# Set parameters for generation
generated_ids = model.generate(
    inputs["input_ids"],
    max_new_tokens=50,  # Specify the number of new tokens to generate
    num_beams=5,  # Beam search for better quality text
    no_repeat_ngram_size=2,  # Prevent repetition
    early_stopping=True  # Stop when the model is confident
)

# Decode the generated text
generated_text = tokenizer.decode(generated_ids[0], skip_special_tokens=True)

print(f"Generated text: {generated_text}")
# Out:
# pytorch_model.bin:   0%|          | 0.00/1.56G [00:00<?, ?B/s]
# ...

# %% [markdown]
# ##Bio-Mistral: RAM Died

# %% [markdown]
# Token: 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

# %%
# !huggingface-cli login

# %%
from transformers import AutoTokenizer, AutoModelForCausalLM, pipeline

# Load the pre-trained BioMistral model and tokenizer
tokenizer = AutoTokenizer.from_pretrained("BioMistral/BioMistral-7B")
model = AutoModelForCausalLM.from_pretrained("BioMistral/BioMistral-7B")

# Initialize the text generation pipeline
generator = pipeline('text-generation', model=model, tokenizer=tokenizer)

input_text = """
Patient notes: INDICATION:  ___ year old man with congenital hepatic fibrosis and portal
hypertension  // TIPS revision/thrombectomy - seen by Dr. ___ ___

COMPARISON:  CT of the abdomen pelvis dated ___

TECHNIQUE:  OPERATORS: Dr. ___ Dr. ___ Interventional
___ and Dr. ___ fellow performed the
procedure.  The attending(s) personally supervised the trainee during any key
components of the procedure where applicable and reviewed and agrees with the
findings as reported below.
ANESTHESIA: Moderate sedation was provided by administrating divided doses of
300mcg of fentanyl and 7.5 mg of midazolam throughout the total intra-service
time of 7 hours and 58 minutes during which the patient's hemodynamic
parameters were continuously monitored by an independent trained radiology
nurse.  1% lidocaine was injected in the skin and subcutaneous tissues
overlying the access site.
MEDICATIONS: 4 mg intravenous tPA delivered through TIPS sheath
CONTRAST: 235 ml of Optiray contrast
FLUOROSCOPY TIME AND DOSE:  184.6 minutes, 2710 mGy

PROCEDURE:
1. Right internal jugular venous access using ultrasound.
2. Pre-procedure right atrial pressure measurements
3. Percutaneous transhepatic access into the TIPS stent.
4. Retrograde snaring of the percutaneous access into the right IJ
5. Trans jugular approach direct access into the upper portion of the
pre-existing TIPS stent
6. Cone beam CT of the TIPS and portal venous system prior to placement of the
new direct TIPS into the pre-existing TIPS
7. Placement of a 10 mm x 6 cm + 2 cm Viatorr partially-covered stent
8. Post-stenting balloon angioplasty of the TIPS shunt and portal vein with a
10 mm balloon.
9. Post-stenting portal venograms.
10. Extension of the cranial portion of the new portosystemic shunt (DIPS)
using a 12 x 40 x 75 lumenneX stent
___. Aspiration thrombectomy of the main portal vein and TIPS stent using a
penumbra device- CAT 8 system
12. TPA administration via the TIPS sheath
13. Gel-Foam pledget tract embolization of the percutaneous transhepatic TIPS
access
14. Placement of a tPA infusion catheter into the portal vein/SMV for
resistant clot
15. A double-lumen PICC was placed via patent right basilic vein


PROCEDURE DETAILS: Following the discussion of the risks, benefits and
alternatives to the procedure, written informed consent was obtained from the
patient. The patient was then brought to the angiography suite and placed
supine on the exam table. A pre-procedure time-out was performed per ___
protocol.  The right neck and abdomen were prepped and draped in the usual
sterile fashion.

Under continuous ultrasound guidance, the patent right internal jugular vein
was compressible and accessed using a micropuncture needle.  Images of
ultrasound access were stored on PACS. Subsequently a Nitinol wire was passed
into the right atrium using fluoroscopic guidance. A small incision was made
at the needle entry site. The needle was exchanged for a micropuncture sheath.
The Nitinol wire was removed and a ___ wire was advanced distally into
the IVC.

The micropuncture sheath was then removed and a 10 ___ sheath was advanced
over the wire into the inferior vena cava.  Right atrium pressure measurements
were obtained.  Multiple 5 ___ catheters including an MPA, SOS, C2 modified
___ catheters were used to attempt access into the existing TIPS.  These were
unsuccessful initially.  Access into the existing TIPS was then obtained using
a TIPS set.  The TIPS cannula device was inserted over the Amplatz wire and
the wire was exchanged for a long Chiba needle. The needle was then advanced
through liver parenchyma.  Upon access into the existing TIPS, a J-tip wire
was introduced into the catheter to pass into the portal vein via the TIPS,
with care taken not to traverse the interstices of the portal end of the TIPS.
A straight flush catheter was advanced over the wire and a contrast enhanced
portal venogram was performed.  Once access had been achieved into the TIPS,
the direct TIPS tract was angioplasties up to 10 mm.

Percutaneous transhepatic TIPS access was achieved into the mid portion of the
TIPS using a 20 gauge Chiba needle.  Stiff 018 v 18 wire was then advanced
into the existing TIPS.  This was snared through the direct right IJV approach
TIPS access sheath into the right IJ for through and through access.  Once
access was established into the portal system, this was converted into an 035
system using several exchanges involving Rubicon catheters and multiple 035
wires including stiff glide, glide and Amplatz wires.

Attempts at retrograde wire access to the cranial portion of the occluded TIPS
via the percutaneous transhepatic access were unsuccessful after multiple
attempts.  A cone beam CT was then performed.
 Rotational cone-beam CT angiography was performed to help delineate the
anatomy.  Multiplanar CT images were reconstructed and 3D volume-rendered
images of the venous anatomy required post-processing on an independent
workstation under direct physician ___.  These images were used in the
interpretation, decision making for intervention and reporting of this
procedure.
Next, through the new tranjugular direct TIPS access, the TIPS itself and the
main portal vein were treated with 10mm plasty using high-pressure balloons.
Post plasty venography was performed which demonstrated clot burden in the
main portal vein in TIPS with little flow through the TIPS itself.  Further
balloon plasty was performed at several locations, as documented.  Once
appropriate opacification of the main portal vein was confirmed, a new  10 x 6
+ 2 cm Viatorr partially-covered stent was advanced into appropriate position
and deployed. Following stent deployment, the stent was dilated using a 10 mm
balloon.

Post stenting venography demonstrated significant clot burden and irregular
appearance of the superior portion of the stent.  Another cone beam CT was
therefore performed to delineate anatomy and interventional planning.

Rotational cone-beam CT angiography was performed to help delineate the
anatomy.  Multiplanar CT images were reconstructed and 3D volume-rendered
images of the venous anatomy required post-processing on an independent
workstation under direct physician ___.  These images were used in the
interpretation, decision making for intervention and reporting of this
procedure.
A decision was made to line the cranial aspect of the new direct TIPS with and
uncovered 12 x 40 x 75 luminnex stent.  This was deployed in the appropriate
position with care being taken to avoid stent migration.  Post repeat stenting
balloon plasty was performed up to 12 mm.  This included portions of the
direct TIPS, the pre-existing TIPS as well as the main portal vein.  Post
plasty injections demonstrated still significant clot burden within the main
portal vein and tributaries.  A decision was made to apply aspiration
thrombectomy using a penumbra device-CAT 8.

Post aspiration thrombectomy venography demonstrated improved patency of the
main portal vein on post venography with minimal flow through the TIPS.  The
diagnostic venography was medically necessary given the absence of recent
catheter venography. TPA was administered into the TIPS stent via the TIPS
sheath.  However, the TIPS itself remained potentially thrombosed.  It was
therefore decided to leave a ___ thrombolysis infusion
catheter in place overnight for tPA administration.
The sheath was then secured to the skin at the right neck site using an 0 silk
suture.  The infusion catheter was secured to the outer sheath.  A sterile
dressing was applied.
The percutaneous transhepatic access was embolized using Gelfoam pledgets.  A
sterile dressing was applied. Limited US did not demonstrate any ___
fluid post tract embolization.
Next, the right arm was prepped and draped in the usual sterile fashion.
Under ultrasound guidance, the patent basilic vein was accessed.  A
double-lumen PICC was inserted with the tip of the PICC in the SVC.  The line
was flushed, secured to the skin and a sterile dressing was applied.

The patient tolerated the procedure well.  There were no immediate
post-procedure complications. The patient was transferred to the ICU in stable
condition.

FINDINGS:


1. Pre-TIPS right atrial pressure of 20 mmHg.
2. Occluded indwelling TIPS with inability to get access via transjugular
approach initially
3. Successful percutaneous access the occluded TIPS using a 20 gauge Chiba
needle.  An 018 wire was then snared superiorly through the right IJ approach
sheath
4. Direct TIPS access venography demonstrated significant clot burden within
the main portal vein.
5. Cone beam CT demonstrated occluded TIPS with passage of access wires within
the stent without evidence for crossing interstices of the portal end of the
TIPS.
6. Post new TIPS extension right atrial pressure of 20 and portal pressure of
45 resulting in portosystemic gradient of 25 mmHg.
7. Successful balloon angioplasty of the main portal vein.  Angioplasty of the
indwelling TIPS and TIPS was also performed up to 10 mm.
8.
9. Post plasty venography demonstrated large decompressive left upper quadrant
gastric varices and other upper abdominal collateral venous channels.  There
was significant thrombosis of the main portal vein.
10. Post plasty venography demonstrated significant clot burden within the
main portal vein and TIPS.  Aspiration thrombectomy of the main portal vein
and TIPS was performed using the penumbra aspiration device with significant
debulking of clot post aspiration thrombectomy.
 11. Post plasty cone beam CT demonstrated an irregular narrowing at the
cranial portion of the new portosystemic shunt.  This was successfully lined
using an  uncovered 12 x 40 x 75 luminnex stent
___. Post plasty and application of the aspiration catheter venography
demonstrated patent main portal vein.  The TIPS was occluded at the end of the
procedure.
13. A 4 ___ ___ lysis catheter was placed in main portal vein
for tPA infusion
14. Gel-Foam pledget tract embolization of the percutaneous transhepatic TIPS
access.  Post tract embolization focused ultrasound demonstrated no evidence
of local hematoma.
15. A double-lumen PICC was placed via patent right basilic vein with tip in
the distal SVC.

IMPRESSION:

Successful right internal jugular access with direct transjugular intrahepatic
portosystemic shunt revision with extension of the TIPS cranially.

New direct TIPS aspiration thrombectomy.

Thrombolysis catheter placement through the right IJ sheath for overnight
thrombolysis


Insurance policy: CT Maxillofacial without contrast (CPT® 70486) or CT Sinus, limited without contrast
(CPT® 76380) is indicated in those with suspicion of Upper Airway Cough Syndrome
(UACS) in the following:4,5,6
o Clinical criteria for chronic rhinosinusitis (CRS) or acute/recurrent rhinosinusitis
are met, as per Sinus and Facial Imaging (HD 29.1) ; OR ALL of the following:
 At least a one week trial of daily antihistamine/decongestant
 Initial evaluation with a chest x-ray and/or CT Chest after the current episode
of cough started or changed
 All medications known to cause cough have been discontinued
Question: Is this service considered medically necessary for the patient? If not, what additional information could be included for the service to be considered medically necessary?
"""

# Generate text
generated_text = generator(input_text, max_new_tokens=150, num_beams=5, no_repeat_ngram_size=2, early_stopping=True)

# Print the generated text
print(generated_text[0]['generated_text'])
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:89: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# tokenizer_config.json:   0%|          | 0.00/1.42k [00:00<?, ?B/s]
# tokenizer.model:   0%|          | 0.00/493k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.80M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/72.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/567 [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/14.5G [00:00<?, ?B/s]

# %%
from transformers import pipeline
gen = pipeline("text-generation", model="BioMistral/BioMistral-7B-DARE")

result = gen("Is this service considered medically necessary for a patient with the following information? If not, what additional information could be included for the service to be considered medically necessary? Mike is 41 year diabetes patient that is having shortness of breath. The service is insulin medication.", max_new_tokens=50)

print(result)

# %%
question_answerer = pipeline("text-generation", model="BioMistral/BioMistral-7B")
result = question_answerer(
    question="Is this service considered medically necessary for a patient with the following information? If not, what additional information could be included for the service to be considered medically necessary?",
    context="Mike is 41 year diabetes patient that is having shortness of breath.",
)

print(result)

# %% [markdown]
# ##Gemma-2: RAM Died Again

# %%
# Load model directly
from transformers import AutoTokenizer, AutoModelForCausalLM

tokenizer = AutoTokenizer.from_pretrained("google/gemma-2-9b")
model = AutoModelForCausalLM.from_pretrained("google/gemma-2-9b")

# Define the prompt

prompt = '''
INDICATION:  ___ year old man with congenital hepatic fibrosis and portal
hypertension  // TIPS revision/thrombectomy - seen by Dr. ___ ___

COMPARISON:  CT of the abdomen pelvis dated ___

TECHNIQUE:  OPERATORS: Dr. ___ Dr. ___ Interventional
___ and Dr. ___ fellow performed the
procedure.  The attending(s) personally supervised the trainee during any key
components of the procedure where applicable and reviewed and agrees with the
findings as reported below.
ANESTHESIA: Moderate sedation was provided by administrating divided doses of
300mcg of fentanyl and 7.5 mg of midazolam throughout the total intra-service
time of 7 hours and 58 minutes during which the patient's hemodynamic
parameters were continuously monitored by an independent trained radiology
nurse.  1% lidocaine was injected in the skin and subcutaneous tissues
overlying the access site.
MEDICATIONS: 4 mg intravenous tPA delivered through TIPS sheath
CONTRAST: 235 ml of Optiray contrast
FLUOROSCOPY TIME AND DOSE:  184.6 minutes, 2710 mGy

PROCEDURE:
1. Right internal jugular venous access using ultrasound.
2. Pre-procedure right atrial pressure measurements
3. Percutaneous transhepatic access into the TIPS stent.
4. Retrograde snaring of the percutaneous access into the right IJ
5. Trans jugular approach direct access into the upper portion of the
pre-existing TIPS stent
6. Cone beam CT of the TIPS and portal venous system prior to placement of the
new direct TIPS into the pre-existing TIPS
7. Placement of a 10 mm x 6 cm + 2 cm Viatorr partially-covered stent
8. Post-stenting balloon angioplasty of the TIPS shunt and portal vein with a
10 mm balloon.
9. Post-stenting portal venograms.
10. Extension of the cranial portion of the new portosystemic shunt (DIPS)
using a 12 x 40 x 75 lumenneX stent
___. Aspiration thrombectomy of the main portal vein and TIPS stent using a
penumbra device- CAT 8 system
12. TPA administration via the TIPS sheath
13. Gel-Foam pledget tract embolization of the percutaneous transhepatic TIPS
access
14. Placement of a tPA infusion catheter into the portal vein/SMV for
resistant clot
15. A double-lumen PICC was placed via patent right basilic vein


PROCEDURE DETAILS: Following the discussion of the risks, benefits and
alternatives to the procedure, written informed consent was obtained from the
patient. The patient was then brought to the angiography suite and placed
supine on the exam table. A pre-procedure time-out was performed per ___
protocol.  The right neck and abdomen were prepped and draped in the usual
sterile fashion.

Under continuous ultrasound guidance, the patent right internal jugular vein
was compressible and accessed using a micropuncture needle.  Images of
ultrasound access were stored on PACS. Subsequently a Nitinol wire was passed
into the right atrium using fluoroscopic guidance. A small incision was made
at the needle entry site. The needle was exchanged for a micropuncture sheath.
The Nitinol wire was removed and a ___ wire was advanced distally into
the IVC.

The micropuncture sheath was then removed and a 10 ___ sheath was advanced
over the wire into the inferior vena cava.  Right atrium pressure measurements
were obtained.  Multiple 5 ___ catheters including an MPA, SOS, C2 modified
___ catheters were used to attempt access into the existing TIPS.  These were
unsuccessful initially.  Access into the existing TIPS was then obtained using
a TIPS set.  The TIPS cannula device was inserted over the Amplatz wire and
the wire was exchanged for a long Chiba needle. The needle was then advanced
through liver parenchyma.  Upon access into the existing TIPS, a J-tip wire
was introduced into the catheter to pass into the portal vein via the TIPS,
with care taken not to traverse the interstices of the portal end of the TIPS.
A straight flush catheter was advanced over the wire and a contrast enhanced
portal venogram was performed.  Once access had been achieved into the TIPS,
the direct TIPS tract was angioplasties up to 10 mm.

Percutaneous transhepatic TIPS access was achieved into the mid portion of the
TIPS using a 20 gauge Chiba needle.  Stiff 018 v 18 wire was then advanced
into the existing TIPS.  This was snared through the direct right IJV approach
TIPS access sheath into the right IJ for through and through access.  Once
access was established into the portal system, this was converted into an 035
system using several exchanges involving Rubicon catheters and multiple 035
wires including stiff glide, glide and Amplatz wires.

Attempts at retrograde wire access to the cranial portion of the occluded TIPS
via the percutaneous transhepatic access were unsuccessful after multiple
attempts.  A cone beam CT was then performed.
 Rotational cone-beam CT angiography was performed to help delineate the
anatomy.  Multiplanar CT images were reconstructed and 3D volume-rendered
images of the venous anatomy required post-processing on an independent
workstation under direct physician ___.  These images were used in the
interpretation, decision making for intervention and reporting of this
procedure.
Next, through the new tranjugular direct TIPS access, the TIPS itself and the
main portal vein were treated with 10mm plasty using high-pressure balloons.
Post plasty venography was performed which demonstrated clot burden in the
main portal vein in TIPS with little flow through the TIPS itself.  Further
balloon plasty was performed at several locations, as documented.  Once
appropriate opacification of the main portal vein was confirmed, a new  10 x 6
+ 2 cm Viatorr partially-covered stent was advanced into appropriate position
and deployed. Following stent deployment, the stent was dilated using a 10 mm
balloon.

Post stenting venography demonstrated significant clot burden and irregular
appearance of the superior portion of the stent.  Another cone beam CT was
therefore performed to delineate anatomy and interventional planning.

Rotational cone-beam CT angiography was performed to help delineate the
anatomy.  Multiplanar CT images were reconstructed and 3D volume-rendered
images of the venous anatomy required post-processing on an independent
workstation under direct physician ___.  These images were used in the
interpretation, decision making for intervention and reporting of this
procedure.
A decision was made to line the cranial aspect of the new direct TIPS with and
uncovered 12 x 40 x 75 luminnex stent.  This was deployed in the appropriate
position with care being taken to avoid stent migration.  Post repeat stenting
balloon plasty was performed up to 12 mm.  This included portions of the
direct TIPS, the pre-existing TIPS as well as the main portal vein.  Post
plasty injections demonstrated still significant clot burden within the main
portal vein and tributaries.  A decision was made to apply aspiration
thrombectomy using a penumbra device-CAT 8.

Post aspiration thrombectomy venography demonstrated improved patency of the
main portal vein on post venography with minimal flow through the TIPS.  The
diagnostic venography was medically necessary given the absence of recent
catheter venography. TPA was administered into the TIPS stent via the TIPS
sheath.  However, the TIPS itself remained potentially thrombosed.  It was
therefore decided to leave a ___ thrombolysis infusion
catheter in place overnight for tPA administration.
The sheath was then secured to the skin at the right neck site using an 0 silk
suture.  The infusion catheter was secured to the outer sheath.  A sterile
dressing was applied.
The percutaneous transhepatic access was embolized using Gelfoam pledgets.  A
sterile dressing was applied. Limited US did not demonstrate any ___
fluid post tract embolization.
Next, the right arm was prepped and draped in the usual sterile fashion.
Under ultrasound guidance, the patent basilic vein was accessed.  A
double-lumen PICC was inserted with the tip of the PICC in the SVC.  The line
was flushed, secured to the skin and a sterile dressing was applied.

The patient tolerated the procedure well.  There were no immediate
post-procedure complications. The patient was transferred to the ICU in stable
condition.

FINDINGS:


1. Pre-TIPS right atrial pressure of 20 mmHg.
2. Occluded indwelling TIPS with inability to get access via transjugular
approach initially
3. Successful percutaneous access the occluded TIPS using a 20 gauge Chiba
needle.  An 018 wire was then snared superiorly through the right IJ approach
sheath
4. Direct TIPS access venography demonstrated significant clot burden within
the main portal vein.
5. Cone beam CT demonstrated occluded TIPS with passage of access wires within
the stent without evidence for crossing interstices of the portal end of the
TIPS.
6. Post new TIPS extension right atrial pressure of 20 and portal pressure of
45 resulting in portosystemic gradient of 25 mmHg.
7. Successful balloon angioplasty of the main portal vein.  Angioplasty of the
indwelling TIPS and TIPS was also performed up to 10 mm.
8.
9. Post plasty venography demonstrated large decompressive left upper quadrant
gastric varices and other upper abdominal collateral venous channels.  There
was significant thrombosis of the main portal vein.
10. Post plasty venography demonstrated significant clot burden within the
main portal vein and TIPS.  Aspiration thrombectomy of the main portal vein
and TIPS was performed using the penumbra aspiration device with significant
debulking of clot post aspiration thrombectomy.
 11. Post plasty cone beam CT demonstrated an irregular narrowing at the
cranial portion of the new portosystemic shunt.  This was successfully lined
using an  uncovered 12 x 40 x 75 luminnex stent
___. Post plasty and application of the aspiration catheter venography
demonstrated patent main portal vein.  The TIPS was occluded at the end of the
procedure.
13. A 4 ___ ___ lysis catheter was placed in main portal vein
for tPA infusion
14. Gel-Foam pledget tract embolization of the percutaneous transhepatic TIPS
access.  Post tract embolization focused ultrasound demonstrated no evidence
of local hematoma.
15. A double-lumen PICC was placed via patent right basilic vein with tip in
the distal SVC.

IMPRESSION:

Successful right internal jugular access with direct transjugular intrahepatic
portosystemic shunt revision with extension of the TIPS cranially.

New direct TIPS aspiration thrombectomy.

Thrombolysis catheter placement through the right IJ sheath for overnight
thrombolysis

Is this service considered medically necessary for a patient with the following information?
If not, what additional information could be included for the service to be considered medically necessary?
'''

insurance_policy = '''CT Maxillofacial without contrast (CPT® 70486) or CT Sinus, limited without contrast
(CPT® 76380) is indicated in those with suspicion of Upper Airway Cough Syndrome
(UACS) in the following:4,5,6
o Clinical criteria for chronic rhinosinusitis (CRS) or acute/recurrent rhinosinusitis
are met, as per Sinus and Facial Imaging (HD 29.1) ; OR ALL of the following:
 At least a one week trial of daily antihistamine/decongestant
 Initial evaluation with a chest x-ray and/or CT Chest after the current episode
of cough started or changed
 All medications known to cause cough have been discontinued'''


# Tokenize the prompt
inputs = tokenizer(prompt, insurance_policy, truncation=True, padding=True, return_tensors="pt")

# Generate text based on the prompt
# Increased max_length to accommodate the input length or use max_new_tokens
output = model.generate(input_ids=inputs['input_ids'], max_length=30000, num_return_sequences=1, early_stopping=True)
# alternatively:
#output = model.generate(input_ids=inputs['input_ids'], max_new_tokens=100, num_return_sequences=1, early_stopping=True)

# Decode and print the output
generated_text = tokenizer.decode(output[0], skip_special_tokens=True)
print(generated_text)

# %% [markdown]
# ##GPT-2: WORKING NOT USEFUL RESPONSE

# %%
# Load model directly
from transformers import AutoTokenizer, AutoModelForCausalLM

tokenizer = AutoTokenizer.from_pretrained("openai-community/gpt2")
model = AutoModelForCausalLM.from_pretrained("openai-community/gpt2")

# %%
# Example input text
text = '''Patient notes: INDICATION:  ___ year old man with congenital hepatic fibrosis and portal
hypertension  // TIPS revision/thrombectomy - seen by Dr. ___ ___

COMPARISON:  CT of the abdomen pelvis dated ___

TECHNIQUE:  OPERATORS: Dr. ___ Dr. ___ Interventional
___ and Dr. ___ fellow performed the
procedure.  The attending(s) personally supervised the trainee during any key
components of the procedure where applicable and reviewed and agrees with the
findings as reported below.
ANESTHESIA: Moderate sedation was provided by administrating divided doses of
300mcg of fentanyl and 7.5 mg of midazolam throughout the total intra-service
time of 7 hours and 58 minutes during which the patient's hemodynamic
parameters were continuously monitored by an independent trained radiology
nurse.  1% lidocaine was injected in the skin and subcutaneous tissues
overlying the access site.
MEDICATIONS: 4 mg intravenous tPA delivered through TIPS sheath
CONTRAST: 235 ml of Optiray contrast
FLUOROSCOPY TIME AND DOSE:  184.6 minutes, 2710 mGy

PROCEDURE:
1. Right internal jugular venous access using ultrasound.
2. Pre-procedure right atrial pressure measurements
3. Percutaneous transhepatic access into the TIPS stent.
4. Retrograde snaring of the percutaneous access into the right IJ
5. Trans jugular approach direct access into the upper portion of the
pre-existing TIPS stent
6. Cone beam CT of the TIPS and portal venous system prior to placement of the
new direct TIPS into the pre-existing TIPS
7. Placement of a 10 mm x 6 cm + 2 cm Viatorr partially-covered stent
8. Post-stenting balloon angioplasty of the TIPS shunt and portal vein with a
10 mm balloon.
9. Post-stenting portal venograms.
10. Extension of the cranial portion of the new portosystemic shunt (DIPS)
using a 12 x 40 x 75 lumenneX stent
___. Aspiration thrombectomy of the main portal vein and TIPS stent using a
penumbra device- CAT 8 system
12. TPA administration via the TIPS sheath
13. Gel-Foam pledget tract embolization of the percutaneous transhepatic TIPS
access
14. Placement of a tPA infusion catheter into the portal vein/SMV for
resistant clot
15. A double-lumen PICC was placed via patent right basilic vein


PROCEDURE DETAILS: Following the discussion of the risks, benefits and
alternatives to the procedure, written informed consent was obtained from the
patient. The patient was then brought to the angiography suite and placed
supine on the exam table. A pre-procedure time-out was performed per ___
protocol.  The right neck and abdomen were prepped and draped in the usual
sterile fashion.

Under continuous ultrasound guidance, the patent right internal jugular vein
was compressible and accessed using a micropuncture needle.  Images of
ultrasound access were stored on PACS. Subsequently a Nitinol wire was passed
into the right atrium using fluoroscopic guidance. A small incision was made
at the needle entry site. The needle was exchanged for a micropuncture sheath.
The Nitinol wire was removed and a ___ wire was advanced distally into
the IVC.

The micropuncture sheath was then removed and a 10 ___ sheath was advanced
over the wire into the inferior vena cava.  Right atrium pressure measurements
were obtained.  Multiple 5 ___ catheters including an MPA, SOS, C2 modified
___ catheters were used to attempt access into the existing TIPS.  These were
unsuccessful initially.  Access into the existing TIPS was then obtained using
a TIPS set.  The TIPS cannula device was inserted over the Amplatz wire and
the wire was exchanged for a long Chiba needle. The needle was then advanced
through liver parenchyma.  Upon access into the existing TIPS, a J-tip wire
was introduced into the catheter to pass into the portal vein via the TIPS,
with care taken not to traverse the interstices of the portal end of the TIPS.
A straight flush catheter was advanced over the wire and a contrast enhanced
portal venogram was performed.  Once access had been achieved into the TIPS,
the direct TIPS tract was angioplasties up to 10 mm.

Percutaneous transhepatic TIPS access was achieved into the mid portion of the
TIPS using a 20 gauge Chiba needle.  Stiff 018 v 18 wire was then advanced
into the existing TIPS.  This was snared through the direct right IJV approach
TIPS access sheath into the right IJ for through and through access.  Once
access was established into the portal system, this was converted into an 035
system using several exchanges involving Rubicon catheters and multiple 035
wires including stiff glide, glide and Amplatz wires.

Attempts at retrograde wire access to the cranial portion of the occluded TIPS
via the percutaneous transhepatic access were unsuccessful after multiple
attempts.  A cone beam CT was then performed.
 Rotational cone-beam CT angiography was performed to help delineate the
anatomy.  Multiplanar CT images were reconstructed and 3D volume-rendered
images of the venous anatomy required post-processing on an independent
workstation under direct physician ___.  These images were used in the
interpretation, decision making for intervention and reporting of this
procedure.
Next, through the new tranjugular direct TIPS access, the TIPS itself and the
main portal vein were treated with 10mm plasty using high-pressure balloons.
Post plasty venography was performed which demonstrated clot burden in the
main portal vein in TIPS with little flow through the TIPS itself.  Further
balloon plasty was performed at several locations, as documented.  Once
appropriate opacification of the main portal vein was confirmed, a new  10 x 6
+ 2 cm Viatorr partially-covered stent was advanced into appropriate position
and deployed. Following stent deployment, the stent was dilated using a 10 mm
balloon.

Post stenting venography demonstrated significant clot burden and irregular
appearance of the superior portion of the stent.  Another cone beam CT was
therefore performed to delineate anatomy and interventional planning.

Rotational cone-beam CT angiography was performed to help delineate the
anatomy.  Multiplanar CT images were reconstructed and 3D volume-rendered
images of the venous anatomy required post-processing on an independent
workstation under direct physician ___.  These images were used in the
interpretation, decision making for intervention and reporting of this
procedure.
A decision was made to line the cranial aspect of the new direct TIPS with and
uncovered 12 x 40 x 75 luminnex stent.  This was deployed in the appropriate
position with care being taken to avoid stent migration.  Post repeat stenting
balloon plasty was performed up to 12 mm.  This included portions of the
direct TIPS, the pre-existing TIPS as well as the main portal vein.  Post
plasty injections demonstrated still significant clot burden within the main
portal vein and tributaries.  A decision was made to apply aspiration
thrombectomy using a penumbra device-CAT 8.

Post aspiration thrombectomy venography demonstrated improved patency of the
main portal vein on post venography with minimal flow through the TIPS.  The
diagnostic venography was medically necessary given the absence of recent
catheter venography. TPA was administered into the TIPS stent via the TIPS
sheath.  However, the TIPS itself remained potentially thrombosed.  It was
therefore decided to leave a ___ thrombolysis infusion
catheter in place overnight for tPA administration.
The sheath was then secured to the skin at the right neck site using an 0 silk
suture.  The infusion catheter was secured to the outer sheath.  A sterile
dressing was applied.
The percutaneous transhepatic access was embolized using Gelfoam pledgets.  A
sterile dressing was applied. Limited US did not demonstrate any ___
fluid post tract embolization.
Next, the right arm was prepped and draped in the usual sterile fashion.
Under ultrasound guidance, the patent basilic vein was accessed.  A
double-lumen PICC was inserted with the tip of the PICC in the SVC.  The line
was flushed, secured to the skin and a sterile dressing was applied.

The patient tolerated the procedure well.  There were no immediate
post-procedure complications. The patient was transferred to the ICU in stable
condition.

FINDINGS:


1. Pre-TIPS right atrial pressure of 20 mmHg.
2. Occluded indwelling TIPS with inability to get access via transjugular
approach initially
3. Successful percutaneous access the occluded TIPS using a 20 gauge Chiba
needle.  An 018 wire was then snared superiorly through the right IJ approach
sheath
4. Direct TIPS access venography demonstrated significant clot burden within
the main portal vein.
5. Cone beam CT demonstrated occluded TIPS with passage of access wires within
the stent without evidence for crossing interstices of the portal end of the
TIPS.
6. Post new TIPS extension right atrial pressure of 20 and portal pressure of
45 resulting in portosystemic gradient of 25 mmHg.
7. Successful balloon angioplasty of the main portal vein.  Angioplasty of the
indwelling TIPS and TIPS was also performed up to 10 mm.
8.
9. Post plasty venography demonstrated large decompressive left upper quadrant
gastric varices and other upper abdominal collateral venous channels.  There
was significant thrombosis of the main portal vein.
10. Post plasty venography demonstrated significant clot burden within the
main portal vein and TIPS.  Aspiration thrombectomy of the main portal vein
and TIPS was performed using the penumbra aspiration device with significant
debulking of clot post aspiration thrombectomy.
 11. Post plasty cone beam CT demonstrated an irregular narrowing at the
cranial portion of the new portosystemic shunt.  This was successfully lined
using an  uncovered 12 x 40 x 75 luminnex stent
___. Post plasty and application of the aspiration catheter venography
demonstrated patent main portal vein.  The TIPS was occluded at the end of the
procedure.
13. A 4 ___ ___ lysis catheter was placed in main portal vein
for tPA infusion
14. Gel-Foam pledget tract embolization of the percutaneous transhepatic TIPS
access.  Post tract embolization focused ultrasound demonstrated no evidence
of local hematoma.
15. A double-lumen PICC was placed via patent right basilic vein with tip in
the distal SVC.

IMPRESSION:

Successful right internal jugular access with direct transjugular intrahepatic
portosystemic shunt revision with extension of the TIPS cranially.

New direct TIPS aspiration thrombectomy.

Thrombolysis catheter placement through the right IJ sheath for overnight
thrombolysis


Insurance policy: CT Maxillofacial without contrast (CPT® 70486) or CT Sinus, limited without contrast
(CPT® 76380) is indicated in those with suspicion of Upper Airway Cough Syndrome
(UACS) in the following:4,5,6
o Clinical criteria for chronic rhinosinusitis (CRS) or acute/recurrent rhinosinusitis
are met, as per Sinus and Facial Imaging (HD 29.1) ; OR ALL of the following:
 At least a one week trial of daily antihistamine/decongestant
 Initial evaluation with a chest x-ray and/or CT Chest after the current episode
of cough started or changed
 All medications known to cause cough have been discontinued
Question: Is this service considered medically necessary for the patient? If not, what additional information could be included for the service to be considered medically necessary?
'''

# Tokenize the input text
inputs = tokenizer(text, return_tensors="pt", truncation=True, max_length=512)

# Generate text
# Set parameters for generation
generated_ids = model.generate(
    inputs["input_ids"],
    max_new_tokens=50,  # Specify the number of new tokens to generate
    num_beams=5,  # Beam search for better quality text
    no_repeat_ngram_size=2,  # Prevent repetition
    early_stopping=True  # Stop when the model is confident
)

# Decode the generated text
generated_text = tokenizer.decode(generated_ids[0], skip_special_tokens=True)

print(f"Generated text: {generated_text}")

# %% [markdown]
# ## Mistral: Ran out of Disk

# %%
# !huggingface-cli login
# Out:
#     _|    _|  _|    _|    _|_|_|    _|_|_|  _|_|_|  _|      _|    _|_|_|      _|_|_|_|    _|_|      _|_|_|  _|_|_|_|
#     _|    _|  _|    _|  _|        _|          _|    _|_|    _|  _|            _|        _|    _|  _|        _|
#     _|_|_|_|  _|    _|  _|  _|_|  _|  _|_|    _|    _|  _|  _|  _|  _|_|      _|_|_|    _|_|_|_|  _|        _|_|_|
#     _|    _|  _|    _|  _|    _|  _|    _|    _|    _|    _|_|  _|    _|      _|        _|    _|  _|        _|
#     _|    _|    _|_|      _|_|_|    _|_|_|  _|_|_|  _|      _|    _|_|_|      _|        _|    _|    _|_|_|  _|_|_|_|
#
#     To login, `huggingface_hub` requires a token generated from https://huggingface.co/settings/tokens .
# Enter your token (input will not be visible):

# %%
# Load model directly
from transformers import AutoTokenizer, AutoModelForCausalLM

tokenizer = AutoTokenizer.from_pretrained("mistralai/Mixtral-8x7B-Instruct-v0.1")
model = AutoModelForCausalLM.from_pretrained("mistralai/Mixtral-8x7B-Instruct-v0.1")

input_text = """
Patient notes: INDICATION:  ___ year old man with congenital hepatic fibrosis and portal
hypertension  // TIPS revision/thrombectomy - seen by Dr. ___ ___

COMPARISON:  CT of the abdomen pelvis dated ___

TECHNIQUE:  OPERATORS: Dr. ___ Dr. ___ Interventional
___ and Dr. ___ fellow performed the
procedure.  The attending(s) personally supervised the trainee during any key
components of the procedure where applicable and reviewed and agrees with the
findings as reported below.
ANESTHESIA: Moderate sedation was provided by administrating divided doses of
300mcg of fentanyl and 7.5 mg of midazolam throughout the total intra-service
time of 7 hours and 58 minutes during which the patient's hemodynamic
parameters were continuously monitored by an independent trained radiology
nurse.  1% lidocaine was injected in the skin and subcutaneous tissues
overlying the access site.
MEDICATIONS: 4 mg intravenous tPA delivered through TIPS sheath
CONTRAST: 235 ml of Optiray contrast
FLUOROSCOPY TIME AND DOSE:  184.6 minutes, 2710 mGy

PROCEDURE:
1. Right internal jugular venous access using ultrasound.
2. Pre-procedure right atrial pressure measurements
3. Percutaneous transhepatic access into the TIPS stent.
4. Retrograde snaring of the percutaneous access into the right IJ
5. Trans jugular approach direct access into the upper portion of the
pre-existing TIPS stent
6. Cone beam CT of the TIPS and portal venous system prior to placement of the
new direct TIPS into the pre-existing TIPS
7. Placement of a 10 mm x 6 cm + 2 cm Viatorr partially-covered stent
8. Post-stenting balloon angioplasty of the TIPS shunt and portal vein with a
10 mm balloon.
9. Post-stenting portal venograms.
10. Extension of the cranial portion of the new portosystemic shunt (DIPS)
using a 12 x 40 x 75 lumenneX stent
___. Aspiration thrombectomy of the main portal vein and TIPS stent using a
penumbra device- CAT 8 system
12. TPA administration via the TIPS sheath
13. Gel-Foam pledget tract embolization of the percutaneous transhepatic TIPS
access
14. Placement of a tPA infusion catheter into the portal vein/SMV for
resistant clot
15. A double-lumen PICC was placed via patent right basilic vein


PROCEDURE DETAILS: Following the discussion of the risks, benefits and
alternatives to the procedure, written informed consent was obtained from the
patient. The patient was then brought to the angiography suite and placed
supine on the exam table. A pre-procedure time-out was performed per ___
protocol.  The right neck and abdomen were prepped and draped in the usual
sterile fashion.

Under continuous ultrasound guidance, the patent right internal jugular vein
was compressible and accessed using a micropuncture needle.  Images of
ultrasound access were stored on PACS. Subsequently a Nitinol wire was passed
into the right atrium using fluoroscopic guidance. A small incision was made
at the needle entry site. The needle was exchanged for a micropuncture sheath.
The Nitinol wire was removed and a ___ wire was advanced distally into
the IVC.

The micropuncture sheath was then removed and a 10 ___ sheath was advanced
over the wire into the inferior vena cava.  Right atrium pressure measurements
were obtained.  Multiple 5 ___ catheters including an MPA, SOS, C2 modified
___ catheters were used to attempt access into the existing TIPS.  These were
unsuccessful initially.  Access into the existing TIPS was then obtained using
a TIPS set.  The TIPS cannula device was inserted over the Amplatz wire and
the wire was exchanged for a long Chiba needle. The needle was then advanced
through liver parenchyma.  Upon access into the existing TIPS, a J-tip wire
was introduced into the catheter to pass into the portal vein via the TIPS,
with care taken not to traverse the interstices of the portal end of the TIPS.
A straight flush catheter was advanced over the wire and a contrast enhanced
portal venogram was performed.  Once access had been achieved into the TIPS,
the direct TIPS tract was angioplasties up to 10 mm.

Percutaneous transhepatic TIPS access was achieved into the mid portion of the
TIPS using a 20 gauge Chiba needle.  Stiff 018 v 18 wire was then advanced
into the existing TIPS.  This was snared through the direct right IJV approach
TIPS access sheath into the right IJ for through and through access.  Once
access was established into the portal system, this was converted into an 035
system using several exchanges involving Rubicon catheters and multiple 035
wires including stiff glide, glide and Amplatz wires.

Attempts at retrograde wire access to the cranial portion of the occluded TIPS
via the percutaneous transhepatic access were unsuccessful after multiple
attempts.  A cone beam CT was then performed.
 Rotational cone-beam CT angiography was performed to help delineate the
anatomy.  Multiplanar CT images were reconstructed and 3D volume-rendered
images of the venous anatomy required post-processing on an independent
workstation under direct physician ___.  These images were used in the
interpretation, decision making for intervention and reporting of this
procedure.
Next, through the new tranjugular direct TIPS access, the TIPS itself and the
main portal vein were treated with 10mm plasty using high-pressure balloons.
Post plasty venography was performed which demonstrated clot burden in the
main portal vein in TIPS with little flow through the TIPS itself.  Further
balloon plasty was performed at several locations, as documented.  Once
appropriate opacification of the main portal vein was confirmed, a new  10 x 6
+ 2 cm Viatorr partially-covered stent was advanced into appropriate position
and deployed. Following stent deployment, the stent was dilated using a 10 mm
balloon.

Post stenting venography demonstrated significant clot burden and irregular
appearance of the superior portion of the stent.  Another cone beam CT was
therefore performed to delineate anatomy and interventional planning.

Rotational cone-beam CT angiography was performed to help delineate the
anatomy.  Multiplanar CT images were reconstructed and 3D volume-rendered
images of the venous anatomy required post-processing on an independent
workstation under direct physician ___.  These images were used in the
interpretation, decision making for intervention and reporting of this
procedure.
A decision was made to line the cranial aspect of the new direct TIPS with and
uncovered 12 x 40 x 75 luminnex stent.  This was deployed in the appropriate
position with care being taken to avoid stent migration.  Post repeat stenting
balloon plasty was performed up to 12 mm.  This included portions of the
direct TIPS, the pre-existing TIPS as well as the main portal vein.  Post
plasty injections demonstrated still significant clot burden within the main
portal vein and tributaries.  A decision was made to apply aspiration
thrombectomy using a penumbra device-CAT 8.

Post aspiration thrombectomy venography demonstrated improved patency of the
main portal vein on post venography with minimal flow through the TIPS.  The
diagnostic venography was medically necessary given the absence of recent
catheter venography. TPA was administered into the TIPS stent via the TIPS
sheath.  However, the TIPS itself remained potentially thrombosed.  It was
therefore decided to leave a ___ thrombolysis infusion
catheter in place overnight for tPA administration.
The sheath was then secured to the skin at the right neck site using an 0 silk
suture.  The infusion catheter was secured to the outer sheath.  A sterile
dressing was applied.
The percutaneous transhepatic access was embolized using Gelfoam pledgets.  A
sterile dressing was applied. Limited US did not demonstrate any ___
fluid post tract embolization.
Next, the right arm was prepped and draped in the usual sterile fashion.
Under ultrasound guidance, the patent basilic vein was accessed.  A
double-lumen PICC was inserted with the tip of the PICC in the SVC.  The line
was flushed, secured to the skin and a sterile dressing was applied.

The patient tolerated the procedure well.  There were no immediate
post-procedure complications. The patient was transferred to the ICU in stable
condition.

FINDINGS:


1. Pre-TIPS right atrial pressure of 20 mmHg.
2. Occluded indwelling TIPS with inability to get access via transjugular
approach initially
3. Successful percutaneous access the occluded TIPS using a 20 gauge Chiba
needle.  An 018 wire was then snared superiorly through the right IJ approach
sheath
4. Direct TIPS access venography demonstrated significant clot burden within
the main portal vein.
5. Cone beam CT demonstrated occluded TIPS with passage of access wires within
the stent without evidence for crossing interstices of the portal end of the
TIPS.
6. Post new TIPS extension right atrial pressure of 20 and portal pressure of
45 resulting in portosystemic gradient of 25 mmHg.
7. Successful balloon angioplasty of the main portal vein.  Angioplasty of the
indwelling TIPS and TIPS was also performed up to 10 mm.
8.
9. Post plasty venography demonstrated large decompressive left upper quadrant
gastric varices and other upper abdominal collateral venous channels.  There
was significant thrombosis of the main portal vein.
10. Post plasty venography demonstrated significant clot burden within the
main portal vein and TIPS.  Aspiration thrombectomy of the main portal vein
and TIPS was performed using the penumbra aspiration device with significant
debulking of clot post aspiration thrombectomy.
 11. Post plasty cone beam CT demonstrated an irregular narrowing at the
cranial portion of the new portosystemic shunt.  This was successfully lined
using an  uncovered 12 x 40 x 75 luminnex stent
___. Post plasty and application of the aspiration catheter venography
demonstrated patent main portal vein.  The TIPS was occluded at the end of the
procedure.
13. A 4 ___ ___ lysis catheter was placed in main portal vein
for tPA infusion
14. Gel-Foam pledget tract embolization of the percutaneous transhepatic TIPS
access.  Post tract embolization focused ultrasound demonstrated no evidence
of local hematoma.
15. A double-lumen PICC was placed via patent right basilic vein with tip in
the distal SVC.

IMPRESSION:

Successful right internal jugular access with direct transjugular intrahepatic
portosystemic shunt revision with extension of the TIPS cranially.

New direct TIPS aspiration thrombectomy.

Thrombolysis catheter placement through the right IJ sheath for overnight
thrombolysis


Insurance policy: CT Maxillofacial without contrast (CPT® 70486) or CT Sinus, limited without contrast
(CPT® 76380) is indicated in those with suspicion of Upper Airway Cough Syndrome
(UACS) in the following:4,5,6
o Clinical criteria for chronic rhinosinusitis (CRS) or acute/recurrent rhinosinusitis
are met, as per Sinus and Facial Imaging (HD 29.1) ; OR ALL of the following:
 At least a one week trial of daily antihistamine/decongestant
 Initial evaluation with a chest x-ray and/or CT Chest after the current episode
of cough started or changed
 All medications known to cause cough have been discontinued
Question: Is this service considered medically necessary for the patient? If not, what additional information could be included for the service to be considered medically necessary?
"""
input = tokenizer(input_text, truncation=True, padding=True, return_tensors="pt")

# Generate text based on the prompt
output = model.generate(input_ids=input['input_ids'], max_length=30000, num_return_sequences=1, early_stopping=True)

generated_text = tokenizer.decode(output[0], skip_special_tokens=True)
print(generated_text)


# result = generator(input_text, max_length=1000, num_return_sequences=1)

# print(result[0]['generated_text'])

# %%
# Load model directly
from transformers import AutoTokenizer, AutoModelForCausalLM

tokenizer = AutoTokenizer.from_pretrained("openai-community/gpt2")
model = AutoModelForCausalLM.from_pretrained("openai-community/gpt2")

# Define the prompt
prompt = '''
INDICATION:  ___ year old man with congenital hepatic fibrosis and portal
hypertension  // TIPS revision/thrombectomy - seen by Dr. ___ ___

COMPARISON:  CT of the abdomen pelvis dated ___

TECHNIQUE:  OPERATORS: Dr. ___ Dr. ___ Interventional
___ and Dr. ___ fellow performed the
procedure.  The attending(s) personally supervised the trainee during any key
components of the procedure where applicable and reviewed and agrees with the
findings as reported below.
ANESTHESIA: Moderate sedation was provided by administrating divided doses of
300mcg of fentanyl and 7.5 mg of midazolam throughout the total intra-service
time of 7 hours and 58 minutes during which the patient's hemodynamic
parameters were continuously monitored by an independent trained radiology
nurse.  1% lidocaine was injected in the skin and subcutaneous tissues
overlying the access site.
MEDICATIONS: 4 mg intravenous tPA delivered through TIPS sheath
CONTRAST: 235 ml of Optiray contrast
FLUOROSCOPY TIME AND DOSE:  184.6 minutes, 2710 mGy

PROCEDURE:
1. Right internal jugular venous access using ultrasound.
2. Pre-procedure right atrial pressure measurements
3. Percutaneous transhepatic access into the TIPS stent.
4. Retrograde snaring of the percutaneous access into the right IJ
5. Trans jugular approach direct access into the upper portion of the
pre-existing TIPS stent
6. Cone beam CT of the TIPS and portal venous system prior to placement of the
new direct TIPS into the pre-existing TIPS
7. Placement of a 10 mm x 6 cm + 2 cm Viatorr partially-covered stent
8. Post-stenting balloon angioplasty of the TIPS shunt and portal vein with a
10 mm balloon.
9. Post-stenting portal venograms.
10. Extension of the cranial portion of the new portosystemic shunt (DIPS)
using a 12 x 40 x 75 lumenneX stent
___. Aspiration thrombectomy of the main portal vein and TIPS stent using a
penumbra device- CAT 8 system
12. TPA administration via the TIPS sheath
13. Gel-Foam pledget tract embolization of the percutaneous transhepatic TIPS
access
14. Placement of a tPA infusion catheter into the portal vein/SMV for
resistant clot
15. A double-lumen PICC was placed via patent right basilic vein


PROCEDURE DETAILS: Following the discussion of the risks, benefits and
alternatives to the procedure, written informed consent was obtained from the
patient. The patient was then brought to the angiography suite and placed
supine on the exam table. A pre-procedure time-out was performed per ___
protocol.  The right neck and abdomen were prepped and draped in the usual
sterile fashion.

Under continuous ultrasound guidance, the patent right internal jugular vein
was compressible and accessed using a micropuncture needle.  Images of
ultrasound access were stored on PACS. Subsequently a Nitinol wire was passed
into the right atrium using fluoroscopic guidance. A small incision was made
at the needle entry site. The needle was exchanged for a micropuncture sheath.
The Nitinol wire was removed and a ___ wire was advanced distally into
the IVC.

The micropuncture sheath was then removed and a 10 ___ sheath was advanced
over the wire into the inferior vena cava.  Right atrium pressure measurements
were obtained.  Multiple 5 ___ catheters including an MPA, SOS, C2 modified
___ catheters were used to attempt access into the existing TIPS.  These were
unsuccessful initially.  Access into the existing TIPS was then obtained using
a TIPS set.  The TIPS cannula device was inserted over the Amplatz wire and
the wire was exchanged for a long Chiba needle. The needle was then advanced
through liver parenchyma.  Upon access into the existing TIPS, a J-tip wire
was introduced into the catheter to pass into the portal vein via the TIPS,
with care taken not to traverse the interstices of the portal end of the TIPS.
A straight flush catheter was advanced over the wire and a contrast enhanced
portal venogram was performed.  Once access had been achieved into the TIPS,
the direct TIPS tract was angioplasties up to 10 mm.

Percutaneous transhepatic TIPS access was achieved into the mid portion of the
TIPS using a 20 gauge Chiba needle.  Stiff 018 v 18 wire was then advanced
into the existing TIPS.  This was snared through the direct right IJV approach
TIPS access sheath into the right IJ for through and through access.  Once
access was established into the portal system, this was converted into an 035
system using several exchanges involving Rubicon catheters and multiple 035
wires including stiff glide, glide and Amplatz wires.

Attempts at retrograde wire access to the cranial portion of the occluded TIPS
via the percutaneous transhepatic access were unsuccessful after multiple
attempts.  A cone beam CT was then performed.
 Rotational cone-beam CT angiography was performed to help delineate the
anatomy.  Multiplanar CT images were reconstructed and 3D volume-rendered
images of the venous anatomy required post-processing on an independent
workstation under direct physician ___.  These images were used in the
interpretation, decision making for intervention and reporting of this
procedure.
Next, through the new tranjugular direct TIPS access, the TIPS itself and the
main portal vein were treated with 10mm plasty using high-pressure balloons.
Post plasty venography was performed which demonstrated clot burden in the
main portal vein in TIPS with little flow through the TIPS itself.  Further
balloon plasty was performed at several locations, as documented.  Once
appropriate opacification of the main portal vein was confirmed, a new  10 x 6
+ 2 cm Viatorr partially-covered stent was advanced into appropriate position
and deployed. Following stent deployment, the stent was dilated using a 10 mm
balloon.

Post stenting venography demonstrated significant clot burden and irregular
appearance of the superior portion of the stent.  Another cone beam CT was
therefore performed to delineate anatomy and interventional planning.

Rotational cone-beam CT angiography was performed to help delineate the
anatomy.  Multiplanar CT images were reconstructed and 3D volume-rendered
images of the venous anatomy required post-processing on an independent
workstation under direct physician ___.  These images were used in the
interpretation, decision making for intervention and reporting of this
procedure.
A decision was made to line the cranial aspect of the new direct TIPS with and
uncovered 12 x 40 x 75 luminnex stent.  This was deployed in the appropriate
position with care being taken to avoid stent migration.  Post repeat stenting
balloon plasty was performed up to 12 mm.  This included portions of the
direct TIPS, the pre-existing TIPS as well as the main portal vein.  Post
plasty injections demonstrated still significant clot burden within the main
portal vein and tributaries.  A decision was made to apply aspiration
thrombectomy using a penumbra device-CAT 8.

Post aspiration thrombectomy venography demonstrated improved patency of the
main portal vein on post venography with minimal flow through the TIPS.  The
diagnostic venography was medically necessary given the absence of recent
catheter venography. TPA was administered into the TIPS stent via the TIPS
sheath.  However, the TIPS itself remained potentially thrombosed.  It was
therefore decided to leave a ___ thrombolysis infusion
catheter in place overnight for tPA administration.
The sheath was then secured to the skin at the right neck site using an 0 silk
suture.  The infusion catheter was secured to the outer sheath.  A sterile
dressing was applied.
The percutaneous transhepatic access was embolized using Gelfoam pledgets.  A
sterile dressing was applied. Limited US did not demonstrate any ___
fluid post tract embolization.
Next, the right arm was prepped and draped in the usual sterile fashion.
Under ultrasound guidance, the patent basilic vein was accessed.  A
double-lumen PICC was inserted with the tip of the PICC in the SVC.  The line
was flushed, secured to the skin and a sterile dressing was applied.

The patient tolerated the procedure well.  There were no immediate
post-procedure complications. The patient was transferred to the ICU in stable
condition.

FINDINGS:


1. Pre-TIPS right atrial pressure of 20 mmHg.
2. Occluded indwelling TIPS with inability to get access via transjugular
approach initially
3. Successful percutaneous access the occluded TIPS using a 20 gauge Chiba
needle.  An 018 wire was then snared superiorly through the right IJ approach
sheath
4. Direct TIPS access venography demonstrated significant clot burden within
the main portal vein.
5. Cone beam CT demonstrated occluded TIPS with passage of access wires within
the stent without evidence for crossing interstices of the portal end of the
TIPS.
6. Post new TIPS extension right atrial pressure of 20 and portal pressure of
45 resulting in portosystemic gradient of 25 mmHg.
7. Successful balloon angioplasty of the main portal vein.  Angioplasty of the
indwelling TIPS and TIPS was also performed up to 10 mm.
8.
9. Post plasty venography demonstrated large decompressive left upper quadrant
gastric varices and other upper abdominal collateral venous channels.  There
was significant thrombosis of the main portal vein.
10. Post plasty venography demonstrated significant clot burden within the
main portal vein and TIPS.  Aspiration thrombectomy of the main portal vein
and TIPS was performed using the penumbra aspiration device with significant
debulking of clot post aspiration thrombectomy.
 11. Post plasty cone beam CT demonstrated an irregular narrowing at the
cranial portion of the new portosystemic shunt.  This was successfully lined
using an  uncovered 12 x 40 x 75 luminnex stent
___. Post plasty and application of the aspiration catheter venography
demonstrated patent main portal vein.  The TIPS was occluded at the end of the
procedure.
13. A 4 ___ ___ lysis catheter was placed in main portal vein
for tPA infusion
14. Gel-Foam pledget tract embolization of the percutaneous transhepatic TIPS
access.  Post tract embolization focused ultrasound demonstrated no evidence
of local hematoma.
15. A double-lumen PICC was placed via patent right basilic vein with tip in
the distal SVC.

IMPRESSION:

Successful right internal jugular access with direct transjugular intrahepatic
portosystemic shunt revision with extension of the TIPS cranially.

New direct TIPS aspiration thrombectomy.

Thrombolysis catheter placement through the right IJ sheath for overnight
thrombolysis


'''

insurance_policy = '''CT Maxillofacial without contrast (CPT® 70486) or CT Sinus, limited without contrast
(CPT® 76380) is indicated in those with suspicion of Upper Airway Cough Syndrome
(UACS) in the following:4,5,6
o Clinical criteria for chronic rhinosinusitis (CRS) or acute/recurrent rhinosinusitis
are met, as per Sinus and Facial Imaging (HD 29.1) ; OR ALL of the following:
 At least a one week trial of daily antihistamine/decongestant
 Initial evaluation with a chest x-ray and/or CT Chest after the current episode
of cough started or changed
 All medications known to cause cough have been discontinued'''

# Add a padding token to the tokenizer
if tokenizer.pad_token is None:
  tokenizer.pad_token = tokenizer.eos_token

# Tokenize the prompt
inputs = tokenizer(prompt, insurance_policy, truncation=True, padding=True, return_tensors="pt")

vocab_size = tokenizer.vocab_size
if (inputs['input_ids'] >= vocab_size).any():
    raise ValueError("Token IDs are out of the model's vocabulary range")

# Generate text based on the prompt
# Increased max_length to accommodate the input length or use max_new_tokens
#output = model.generate(input_ids=inputs['input_ids'], max_length=1500, num_return_sequences=1, early_stopping=True)
# alternatively:

model.generation_config.pad_token_id = tokenizer.pad_token_id

output = model.generate(
    input_ids=inputs['input_ids'],
    pad_token_id=tokenizer.pad_token_id,
    max_length=2048
)

# Decode and print the output
generated_text = tokenizer.decode(output[0], skip_special_tokens=True)
print(generated_text)

# %% [markdown]
# ##Llama 3: RAM Died Again

# %%
# !huggingface-cli login

# %%
# Load model directly
from transformers import AutoTokenizer, AutoModelForCausalLM

tokenizer = AutoTokenizer.from_pretrained("meta-llama/Meta-Llama-3.1-8B-Instruct")
model = AutoModelForCausalLM.from_pretrained("meta-llama/Meta-Llama-3.1-8B-Instruct")

# %%
prompt = '''
INDICATION:  ___ year old man with congenital hepatic fibrosis and portal
hypertension  // TIPS revision/thrombectomy - seen by Dr. ___ ___

COMPARISON:  CT of the abdomen pelvis dated ___

TECHNIQUE:  OPERATORS: Dr. ___ Dr. ___ Interventional
___ and Dr. ___ fellow performed the
procedure.  The attending(s) personally supervised the trainee during any key
components of the procedure where applicable and reviewed and agrees with the
findings as reported below.
ANESTHESIA: Moderate sedation was provided by administrating divided doses of
300mcg of fentanyl and 7.5 mg of midazolam throughout the total intra-service
time of 7 hours and 58 minutes during which the patient's hemodynamic
parameters were continuously monitored by an independent trained radiology
nurse.  1% lidocaine was injected in the skin and subcutaneous tissues
overlying the access site.
MEDICATIONS: 4 mg intravenous tPA delivered through TIPS sheath
CONTRAST: 235 ml of Optiray contrast
FLUOROSCOPY TIME AND DOSE:  184.6 minutes, 2710 mGy

PROCEDURE:
1. Right internal jugular venous access using ultrasound.
2. Pre-procedure right atrial pressure measurements
3. Percutaneous transhepatic access into the TIPS stent.
4. Retrograde snaring of the percutaneous access into the right IJ
5. Trans jugular approach direct access into the upper portion of the
pre-existing TIPS stent
6. Cone beam CT of the TIPS and portal venous system prior to placement of the
new direct TIPS into the pre-existing TIPS
7. Placement of a 10 mm x 6 cm + 2 cm Viatorr partially-covered stent
8. Post-stenting balloon angioplasty of the TIPS shunt and portal vein with a
10 mm balloon.
9. Post-stenting portal venograms.
10. Extension of the cranial portion of the new portosystemic shunt (DIPS)
using a 12 x 40 x 75 lumenneX stent
___. Aspiration thrombectomy of the main portal vein and TIPS stent using a
penumbra device- CAT 8 system
12. TPA administration via the TIPS sheath
13. Gel-Foam pledget tract embolization of the percutaneous transhepatic TIPS
access
14. Placement of a tPA infusion catheter into the portal vein/SMV for
resistant clot
15. A double-lumen PICC was placed via patent right basilic vein


PROCEDURE DETAILS: Following the discussion of the risks, benefits and
alternatives to the procedure, written informed consent was obtained from the
patient. The patient was then brought to the angiography suite and placed
supine on the exam table. A pre-procedure time-out was performed per ___
protocol.  The right neck and abdomen were prepped and draped in the usual
sterile fashion.

Under continuous ultrasound guidance, the patent right internal jugular vein
was compressible and accessed using a micropuncture needle.  Images of
ultrasound access were stored on PACS. Subsequently a Nitinol wire was passed
into the right atrium using fluoroscopic guidance. A small incision was made
at the needle entry site. The needle was exchanged for a micropuncture sheath.
The Nitinol wire was removed and a ___ wire was advanced distally into
the IVC.

The micropuncture sheath was then removed and a 10 ___ sheath was advanced
over the wire into the inferior vena cava.  Right atrium pressure measurements
were obtained.  Multiple 5 ___ catheters including an MPA, SOS, C2 modified
___ catheters were used to attempt access into the existing TIPS.  These were
unsuccessful initially.  Access into the existing TIPS was then obtained using
a TIPS set.  The TIPS cannula device was inserted over the Amplatz wire and
the wire was exchanged for a long Chiba needle. The needle was then advanced
through liver parenchyma.  Upon access into the existing TIPS, a J-tip wire
was introduced into the catheter to pass into the portal vein via the TIPS,
with care taken not to traverse the interstices of the portal end of the TIPS.
A straight flush catheter was advanced over the wire and a contrast enhanced
portal venogram was performed.  Once access had been achieved into the TIPS,
the direct TIPS tract was angioplasties up to 10 mm.

Percutaneous transhepatic TIPS access was achieved into the mid portion of the
TIPS using a 20 gauge Chiba needle.  Stiff 018 v 18 wire was then advanced
into the existing TIPS.  This was snared through the direct right IJV approach
TIPS access sheath into the right IJ for through and through access.  Once
access was established into the portal system, this was converted into an 035
system using several exchanges involving Rubicon catheters and multiple 035
wires including stiff glide, glide and Amplatz wires.

Attempts at retrograde wire access to the cranial portion of the occluded TIPS
via the percutaneous transhepatic access were unsuccessful after multiple
attempts.  A cone beam CT was then performed.
 Rotational cone-beam CT angiography was performed to help delineate the
anatomy.  Multiplanar CT images were reconstructed and 3D volume-rendered
images of the venous anatomy required post-processing on an independent
workstation under direct physician ___.  These images were used in the
interpretation, decision making for intervention and reporting of this
procedure.
Next, through the new tranjugular direct TIPS access, the TIPS itself and the
main portal vein were treated with 10mm plasty using high-pressure balloons.
Post plasty venography was performed which demonstrated clot burden in the
main portal vein in TIPS with little flow through the TIPS itself.  Further
balloon plasty was performed at several locations, as documented.  Once
appropriate opacification of the main portal vein was confirmed, a new  10 x 6
+ 2 cm Viatorr partially-covered stent was advanced into appropriate position
and deployed. Following stent deployment, the stent was dilated using a 10 mm
balloon.

Post stenting venography demonstrated significant clot burden and irregular
appearance of the superior portion of the stent.  Another cone beam CT was
therefore performed to delineate anatomy and interventional planning.

Rotational cone-beam CT angiography was performed to help delineate the
anatomy.  Multiplanar CT images were reconstructed and 3D volume-rendered
images of the venous anatomy required post-processing on an independent
workstation under direct physician ___.  These images were used in the
interpretation, decision making for intervention and reporting of this
procedure.
A decision was made to line the cranial aspect of the new direct TIPS with and
uncovered 12 x 40 x 75 luminnex stent.  This was deployed in the appropriate
position with care being taken to avoid stent migration.  Post repeat stenting
balloon plasty was performed up to 12 mm.  This included portions of the
direct TIPS, the pre-existing TIPS as well as the main portal vein.  Post
plasty injections demonstrated still significant clot burden within the main
portal vein and tributaries.  A decision was made to apply aspiration
thrombectomy using a penumbra device-CAT 8.

Post aspiration thrombectomy venography demonstrated improved patency of the
main portal vein on post venography with minimal flow through the TIPS.  The
diagnostic venography was medically necessary given the absence of recent
catheter venography. TPA was administered into the TIPS stent via the TIPS
sheath.  However, the TIPS itself remained potentially thrombosed.  It was
therefore decided to leave a ___ thrombolysis infusion
catheter in place overnight for tPA administration.
The sheath was then secured to the skin at the right neck site using an 0 silk
suture.  The infusion catheter was secured to the outer sheath.  A sterile
dressing was applied.
The percutaneous transhepatic access was embolized using Gelfoam pledgets.  A
sterile dressing was applied. Limited US did not demonstrate any ___
fluid post tract embolization.
Next, the right arm was prepped and draped in the usual sterile fashion.
Under ultrasound guidance, the patent basilic vein was accessed.  A
double-lumen PICC was inserted with the tip of the PICC in the SVC.  The line
was flushed, secured to the skin and a sterile dressing was applied.

The patient tolerated the procedure well.  There were no immediate
post-procedure complications. The patient was transferred to the ICU in stable
condition.

FINDINGS:


1. Pre-TIPS right atrial pressure of 20 mmHg.
2. Occluded indwelling TIPS with inability to get access via transjugular
approach initially
3. Successful percutaneous access the occluded TIPS using a 20 gauge Chiba
needle.  An 018 wire was then snared superiorly through the right IJ approach
sheath
4. Direct TIPS access venography demonstrated significant clot burden within
the main portal vein.
5. Cone beam CT demonstrated occluded TIPS with passage of access wires within
the stent without evidence for crossing interstices of the portal end of the
TIPS.
6. Post new TIPS extension right atrial pressure of 20 and portal pressure of
45 resulting in portosystemic gradient of 25 mmHg.
7. Successful balloon angioplasty of the main portal vein.  Angioplasty of the
indwelling TIPS and TIPS was also performed up to 10 mm.
8.
9. Post plasty venography demonstrated large decompressive left upper quadrant
gastric varices and other upper abdominal collateral venous channels.  There
was significant thrombosis of the main portal vein.
10. Post plasty venography demonstrated significant clot burden within the
main portal vein and TIPS.  Aspiration thrombectomy of the main portal vein
and TIPS was performed using the penumbra aspiration device with significant
debulking of clot post aspiration thrombectomy.
 11. Post plasty cone beam CT demonstrated an irregular narrowing at the
cranial portion of the new portosystemic shunt.  This was successfully lined
using an  uncovered 12 x 40 x 75 luminnex stent
___. Post plasty and application of the aspiration catheter venography
demonstrated patent main portal vein.  The TIPS was occluded at the end of the
procedure.
13. A 4 ___ ___ lysis catheter was placed in main portal vein
for tPA infusion
14. Gel-Foam pledget tract embolization of the percutaneous transhepatic TIPS
access.  Post tract embolization focused ultrasound demonstrated no evidence
of local hematoma.
15. A double-lumen PICC was placed via patent right basilic vein with tip in
the distal SVC.

IMPRESSION:

Successful right internal jugular access with direct transjugular intrahepatic
portosystemic shunt revision with extension of the TIPS cranially.

New direct TIPS aspiration thrombectomy.

Thrombolysis catheter placement through the right IJ sheath for overnight
thrombolysis

Is this service considered medically necessary for a patient with the following information?
If not, what additional information could be included for the service to be considered medically necessary?
'''

insurance_policy = '''CT Maxillofacial without contrast (CPT® 70486) or CT Sinus, limited without contrast
(CPT® 76380) is indicated in those with suspicion of Upper Airway Cough Syndrome
(UACS) in the following:4,5,6
o Clinical criteria for chronic rhinosinusitis (CRS) or acute/recurrent rhinosinusitis
are met, as per Sinus and Facial Imaging (HD 29.1) ; OR ALL of the following:
 At least a one week trial of daily antihistamine/decongestant
 Initial evaluation with a chest x-ray and/or CT Chest after the current episode
of cough started or changed
 All medications known to cause cough have been discontinued'''


# Tokenize the prompt
inputs = tokenizer(prompt, insurance_policy, truncation=True, padding=True, return_tensors="pt")

# Generate text based on the prompt
# Increased max_length to accommodate the input length or use max_new_tokens
output = model.generate(input_ids=inputs['input_ids'], max_length=30000, num_return_sequences=1, early_stopping=True)
# alternatively:
#output = model.generate(input_ids=inputs['input_ids'], max_new_tokens=100, num_return_sequences=1, early_stopping=True)

# Decode and print the output
generated_text = tokenizer.decode(output[0], skip_special_tokens=True)
print(generated_text)

# %% [markdown]
# ##Meditron: RAM crash

# %%
# !huggingface-cli login

# %%
# Load model directly
from transformers import AutoTokenizer, AutoModelForCausalLM

tokenizer = AutoTokenizer.from_pretrained("epfl-llm/meditron-7b")
model = AutoModelForCausalLM.from_pretrained("epfl-llm/meditron-7b")

# %%
text = '''Patient notes: INDICATION:  ___ year old man with congenital hepatic fibrosis and portal
hypertension  // TIPS revision/thrombectomy - seen by Dr. ___ ___

COMPARISON:  CT of the abdomen pelvis dated ___

TECHNIQUE:  OPERATORS: Dr. ___ Dr. ___ Interventional
___ and Dr. ___ fellow performed the
procedure.  The attending(s) personally supervised the trainee during any key
components of the procedure where applicable and reviewed and agrees with the
findings as reported below.
ANESTHESIA: Moderate sedation was provided by administrating divided doses of
300mcg of fentanyl and 7.5 mg of midazolam throughout the total intra-service
time of 7 hours and 58 minutes during which the patient's hemodynamic
parameters were continuously monitored by an independent trained radiology
nurse.  1% lidocaine was injected in the skin and subcutaneous tissues
overlying the access site.
MEDICATIONS: 4 mg intravenous tPA delivered through TIPS sheath
CONTRAST: 235 ml of Optiray contrast
FLUOROSCOPY TIME AND DOSE:  184.6 minutes, 2710 mGy

PROCEDURE:
1. Right internal jugular venous access using ultrasound.
2. Pre-procedure right atrial pressure measurements
3. Percutaneous transhepatic access into the TIPS stent.
4. Retrograde snaring of the percutaneous access into the right IJ
5. Trans jugular approach direct access into the upper portion of the
pre-existing TIPS stent
6. Cone beam CT of the TIPS and portal venous system prior to placement of the
new direct TIPS into the pre-existing TIPS
7. Placement of a 10 mm x 6 cm + 2 cm Viatorr partially-covered stent
8. Post-stenting balloon angioplasty of the TIPS shunt and portal vein with a
10 mm balloon.
9. Post-stenting portal venograms.
10. Extension of the cranial portion of the new portosystemic shunt (DIPS)
using a 12 x 40 x 75 lumenneX stent
___. Aspiration thrombectomy of the main portal vein and TIPS stent using a
penumbra device- CAT 8 system
12. TPA administration via the TIPS sheath
13. Gel-Foam pledget tract embolization of the percutaneous transhepatic TIPS
access
14. Placement of a tPA infusion catheter into the portal vein/SMV for
resistant clot
15. A double-lumen PICC was placed via patent right basilic vein


PROCEDURE DETAILS: Following the discussion of the risks, benefits and
alternatives to the procedure, written informed consent was obtained from the
patient. The patient was then brought to the angiography suite and placed
supine on the exam table. A pre-procedure time-out was performed per ___
protocol.  The right neck and abdomen were prepped and draped in the usual
sterile fashion.

Under continuous ultrasound guidance, the patent right internal jugular vein
was compressible and accessed using a micropuncture needle.  Images of
ultrasound access were stored on PACS. Subsequently a Nitinol wire was passed
into the right atrium using fluoroscopic guidance. A small incision was made
at the needle entry site. The needle was exchanged for a micropuncture sheath.
The Nitinol wire was removed and a ___ wire was advanced distally into
the IVC.

The micropuncture sheath was then removed and a 10 ___ sheath was advanced
over the wire into the inferior vena cava.  Right atrium pressure measurements
were obtained.  Multiple 5 ___ catheters including an MPA, SOS, C2 modified
___ catheters were used to attempt access into the existing TIPS.  These were
unsuccessful initially.  Access into the existing TIPS was then obtained using
a TIPS set.  The TIPS cannula device was inserted over the Amplatz wire and
the wire was exchanged for a long Chiba needle. The needle was then advanced
through liver parenchyma.  Upon access into the existing TIPS, a J-tip wire
was introduced into the catheter to pass into the portal vein via the TIPS,
with care taken not to traverse the interstices of the portal end of the TIPS.
A straight flush catheter was advanced over the wire and a contrast enhanced
portal venogram was performed.  Once access had been achieved into the TIPS,
the direct TIPS tract was angioplasties up to 10 mm.

Percutaneous transhepatic TIPS access was achieved into the mid portion of the
TIPS using a 20 gauge Chiba needle.  Stiff 018 v 18 wire was then advanced
into the existing TIPS.  This was snared through the direct right IJV approach
TIPS access sheath into the right IJ for through and through access.  Once
access was established into the portal system, this was converted into an 035
system using several exchanges involving Rubicon catheters and multiple 035
wires including stiff glide, glide and Amplatz wires.

Attempts at retrograde wire access to the cranial portion of the occluded TIPS
via the percutaneous transhepatic access were unsuccessful after multiple
attempts.  A cone beam CT was then performed.
 Rotational cone-beam CT angiography was performed to help delineate the
anatomy.  Multiplanar CT images were reconstructed and 3D volume-rendered
images of the venous anatomy required post-processing on an independent
workstation under direct physician ___.  These images were used in the
interpretation, decision making for intervention and reporting of this
procedure.
Next, through the new tranjugular direct TIPS access, the TIPS itself and the
main portal vein were treated with 10mm plasty using high-pressure balloons.
Post plasty venography was performed which demonstrated clot burden in the
main portal vein in TIPS with little flow through the TIPS itself.  Further
balloon plasty was performed at several locations, as documented.  Once
appropriate opacification of the main portal vein was confirmed, a new  10 x 6
+ 2 cm Viatorr partially-covered stent was advanced into appropriate position
and deployed. Following stent deployment, the stent was dilated using a 10 mm
balloon.

Post stenting venography demonstrated significant clot burden and irregular
appearance of the superior portion of the stent.  Another cone beam CT was
therefore performed to delineate anatomy and interventional planning.

Rotational cone-beam CT angiography was performed to help delineate the
anatomy.  Multiplanar CT images were reconstructed and 3D volume-rendered
images of the venous anatomy required post-processing on an independent
workstation under direct physician ___.  These images were used in the
interpretation, decision making for intervention and reporting of this
procedure.
A decision was made to line the cranial aspect of the new direct TIPS with and
uncovered 12 x 40 x 75 luminnex stent.  This was deployed in the appropriate
position with care being taken to avoid stent migration.  Post repeat stenting
balloon plasty was performed up to 12 mm.  This included portions of the
direct TIPS, the pre-existing TIPS as well as the main portal vein.  Post
plasty injections demonstrated still significant clot burden within the main
portal vein and tributaries.  A decision was made to apply aspiration
thrombectomy using a penumbra device-CAT 8.

Post aspiration thrombectomy venography demonstrated improved patency of the
main portal vein on post venography with minimal flow through the TIPS.  The
diagnostic venography was medically necessary given the absence of recent
catheter venography. TPA was administered into the TIPS stent via the TIPS
sheath.  However, the TIPS itself remained potentially thrombosed.  It was
therefore decided to leave a ___ thrombolysis infusion
catheter in place overnight for tPA administration.
The sheath was then secured to the skin at the right neck site using an 0 silk
suture.  The infusion catheter was secured to the outer sheath.  A sterile
dressing was applied.
The percutaneous transhepatic access was embolized using Gelfoam pledgets.  A
sterile dressing was applied. Limited US did not demonstrate any ___
fluid post tract embolization.
Next, the right arm was prepped and draped in the usual sterile fashion.
Under ultrasound guidance, the patent basilic vein was accessed.  A
double-lumen PICC was inserted with the tip of the PICC in the SVC.  The line
was flushed, secured to the skin and a sterile dressing was applied.

The patient tolerated the procedure well.  There were no immediate
post-procedure complications. The patient was transferred to the ICU in stable
condition.

FINDINGS:


1. Pre-TIPS right atrial pressure of 20 mmHg.
2. Occluded indwelling TIPS with inability to get access via transjugular
approach initially
3. Successful percutaneous access the occluded TIPS using a 20 gauge Chiba
needle.  An 018 wire was then snared superiorly through the right IJ approach
sheath
4. Direct TIPS access venography demonstrated significant clot burden within
the main portal vein.
5. Cone beam CT demonstrated occluded TIPS with passage of access wires within
the stent without evidence for crossing interstices of the portal end of the
TIPS.
6. Post new TIPS extension right atrial pressure of 20 and portal pressure of
45 resulting in portosystemic gradient of 25 mmHg.
7. Successful balloon angioplasty of the main portal vein.  Angioplasty of the
indwelling TIPS and TIPS was also performed up to 10 mm.
8.
9. Post plasty venography demonstrated large decompressive left upper quadrant
gastric varices and other upper abdominal collateral venous channels.  There
was significant thrombosis of the main portal vein.
10. Post plasty venography demonstrated significant clot burden within the
main portal vein and TIPS.  Aspiration thrombectomy of the main portal vein
and TIPS was performed using the penumbra aspiration device with significant
debulking of clot post aspiration thrombectomy.
 11. Post plasty cone beam CT demonstrated an irregular narrowing at the
cranial portion of the new portosystemic shunt.  This was successfully lined
using an  uncovered 12 x 40 x 75 luminnex stent
___. Post plasty and application of the aspiration catheter venography
demonstrated patent main portal vein.  The TIPS was occluded at the end of the
procedure.
13. A 4 ___ ___ lysis catheter was placed in main portal vein
for tPA infusion
14. Gel-Foam pledget tract embolization of the percutaneous transhepatic TIPS
access.  Post tract embolization focused ultrasound demonstrated no evidence
of local hematoma.
15. A double-lumen PICC was placed via patent right basilic vein with tip in
the distal SVC.

IMPRESSION:

Successful right internal jugular access with direct transjugular intrahepatic
portosystemic shunt revision with extension of the TIPS cranially.

New direct TIPS aspiration thrombectomy.

Thrombolysis catheter placement through the right IJ sheath for overnight
thrombolysis


Insurance policy: CT Maxillofacial without contrast (CPT® 70486) or CT Sinus, limited without contrast
(CPT® 76380) is indicated in those with suspicion of Upper Airway Cough Syndrome
(UACS) in the following:4,5,6
o Clinical criteria for chronic rhinosinusitis (CRS) or acute/recurrent rhinosinusitis
are met, as per Sinus and Facial Imaging (HD 29.1) ; OR ALL of the following:
 At least a one week trial of daily antihistamine/decongestant
 Initial evaluation with a chest x-ray and/or CT Chest after the current episode
of cough started or changed
 All medications known to cause cough have been discontinued
Question: Is this service considered medically necessary for the patient? If not, what additional information could be included for the service to be considered medically necessary?
'''

# Tokenize the input text
inputs = tokenizer(text, return_tensors="pt", truncation=True, max_length=512)

# Generate text
# Set parameters for generation
generated_ids = model.generate(
    inputs["input_ids"],
    max_new_tokens=50,  # Specify the number of new tokens to generate
    num_beams=5,  # Beam search for better quality text
    no_repeat_ngram_size=2,  # Prevent repetition
    early_stopping=True  # Stop when the model is confident
)

# Decode the generated text
generated_text = tokenizer.decode(generated_ids[0], skip_special_tokens=True)

print(f"Generated text: {generated_text}")

# %% [markdown]
# ##google's T5:

# %%
from transformers import T5Tokenizer, T5ForConditionalGeneration

tokenizer = T5Tokenizer.from_pretrained("google-t5/t5-small")
model = T5ForConditionalGeneration.from_pretrained("google-t5/t5-small")

# Define the prompt
prompt = "Is this service considered medically necessary for a patient with the following information? If not, what additional information could be included for the service to be considered medically necessary? Mike is 41 year diabetes patient that is having shortness of breath. The service is insulin medication."

# Tokenize the prompt
inputs = tokenizer(prompt, return_tensors="pt")

# Generate text based on the prompt
output = model.generate(input_ids=inputs['input_ids'], max_length=150, num_return_sequences=1, early_stopping=True)

# Decode and print the output
generated_text = tokenizer.decode(output[0], skip_special_tokens=True)
print(generated_text)

# %% [markdown]
# ##MedBERT: PROMPT TOO LONG

# %%
# Load model directly
from transformers import AutoTokenizer, AutoModelForMaskedLM

tokenizer = AutoTokenizer.from_pretrained("GerMedBERT/medbert-512")
model = AutoModelForMaskedLM.from_pretrained("GerMedBERT/medbert-512")

# %%
# Example input text
text = '''Patient notes: INDICATION:  ___ year old man with congenital hepatic fibrosis and portal
hypertension  // TIPS revision/thrombectomy - seen by Dr. ___ ___

COMPARISON:  CT of the abdomen pelvis dated ___

TECHNIQUE:  OPERATORS: Dr. ___ Dr. ___ Interventional
___ and Dr. ___ fellow performed the
procedure.  The attending(s) personally supervised the trainee during any key
components of the procedure where applicable and reviewed and agrees with the
findings as reported below.
ANESTHESIA: Moderate sedation was provided by administrating divided doses of
300mcg of fentanyl and 7.5 mg of midazolam throughout the total intra-service
time of 7 hours and 58 minutes during which the patient's hemodynamic
parameters were continuously monitored by an independent trained radiology
nurse.  1% lidocaine was injected in the skin and subcutaneous tissues
overlying the access site.
MEDICATIONS: 4 mg intravenous tPA delivered through TIPS sheath
CONTRAST: 235 ml of Optiray contrast
FLUOROSCOPY TIME AND DOSE:  184.6 minutes, 2710 mGy

PROCEDURE:
1. Right internal jugular venous access using ultrasound.
2. Pre-procedure right atrial pressure measurements
3. Percutaneous transhepatic access into the TIPS stent.
4. Retrograde snaring of the percutaneous access into the right IJ
5. Trans jugular approach direct access into the upper portion of the
pre-existing TIPS stent
6. Cone beam CT of the TIPS and portal venous system prior to placement of the
new direct TIPS into the pre-existing TIPS
7. Placement of a 10 mm x 6 cm + 2 cm Viatorr partially-covered stent
8. Post-stenting balloon angioplasty of the TIPS shunt and portal vein with a
10 mm balloon.
9. Post-stenting portal venograms.
10. Extension of the cranial portion of the new portosystemic shunt (DIPS)
using a 12 x 40 x 75 lumenneX stent
___. Aspiration thrombectomy of the main portal vein and TIPS stent using a
penumbra device- CAT 8 system
12. TPA administration via the TIPS sheath
13. Gel-Foam pledget tract embolization of the percutaneous transhepatic TIPS
access
14. Placement of a tPA infusion catheter into the portal vein/SMV for
resistant clot
15. A double-lumen PICC was placed via patent right basilic vein


PROCEDURE DETAILS: Following the discussion of the risks, benefits and
alternatives to the procedure, written informed consent was obtained from the
patient. The patient was then brought to the angiography suite and placed
supine on the exam table. A pre-procedure time-out was performed per ___
protocol.  The right neck and abdomen were prepped and draped in the usual
sterile fashion.

Under continuous ultrasound guidance, the patent right internal jugular vein
was compressible and accessed using a micropuncture needle.  Images of
ultrasound access were stored on PACS. Subsequently a Nitinol wire was passed
into the right atrium using fluoroscopic guidance. A small incision was made
at the needle entry site. The needle was exchanged for a micropuncture sheath.
The Nitinol wire was removed and a ___ wire was advanced distally into
the IVC.

The micropuncture sheath was then removed and a 10 ___ sheath was advanced
over the wire into the inferior vena cava.  Right atrium pressure measurements
were obtained.  Multiple 5 ___ catheters including an MPA, SOS, C2 modified
___ catheters were used to attempt access into the existing TIPS.  These were
unsuccessful initially.  Access into the existing TIPS was then obtained using
a TIPS set.  The TIPS cannula device was inserted over the Amplatz wire and
the wire was exchanged for a long Chiba needle. The needle was then advanced
through liver parenchyma.  Upon access into the existing TIPS, a J-tip wire
was introduced into the catheter to pass into the portal vein via the TIPS,
with care taken not to traverse the interstices of the portal end of the TIPS.
A straight flush catheter was advanced over the wire and a contrast enhanced
portal venogram was performed.  Once access had been achieved into the TIPS,
the direct TIPS tract was angioplasties up to 10 mm.

Percutaneous transhepatic TIPS access was achieved into the mid portion of the
TIPS using a 20 gauge Chiba needle.  Stiff 018 v 18 wire was then advanced
into the existing TIPS.  This was snared through the direct right IJV approach
TIPS access sheath into the right IJ for through and through access.  Once
access was established into the portal system, this was converted into an 035
system using several exchanges involving Rubicon catheters and multiple 035
wires including stiff glide, glide and Amplatz wires.

Attempts at retrograde wire access to the cranial portion of the occluded TIPS
via the percutaneous transhepatic access were unsuccessful after multiple
attempts.  A cone beam CT was then performed.
 Rotational cone-beam CT angiography was performed to help delineate the
anatomy.  Multiplanar CT images were reconstructed and 3D volume-rendered
images of the venous anatomy required post-processing on an independent
workstation under direct physician ___.  These images were used in the
interpretation, decision making for intervention and reporting of this
procedure.
Next, through the new tranjugular direct TIPS access, the TIPS itself and the
main portal vein were treated with 10mm plasty using high-pressure balloons.
Post plasty venography was performed which demonstrated clot burden in the
main portal vein in TIPS with little flow through the TIPS itself.  Further
balloon plasty was performed at several locations, as documented.  Once
appropriate opacification of the main portal vein was confirmed, a new  10 x 6
+ 2 cm Viatorr partially-covered stent was advanced into appropriate position
and deployed. Following stent deployment, the stent was dilated using a 10 mm
balloon.

Post stenting venography demonstrated significant clot burden and irregular
appearance of the superior portion of the stent.  Another cone beam CT was
therefore performed to delineate anatomy and interventional planning.

Rotational cone-beam CT angiography was performed to help delineate the
anatomy.  Multiplanar CT images were reconstructed and 3D volume-rendered
images of the venous anatomy required post-processing on an independent
workstation under direct physician ___.  These images were used in the
interpretation, decision making for intervention and reporting of this
procedure.
A decision was made to line the cranial aspect of the new direct TIPS with and
uncovered 12 x 40 x 75 luminnex stent.  This was deployed in the appropriate
position with care being taken to avoid stent migration.  Post repeat stenting
balloon plasty was performed up to 12 mm.  This included portions of the
direct TIPS, the pre-existing TIPS as well as the main portal vein.  Post
plasty injections demonstrated still significant clot burden within the main
portal vein and tributaries.  A decision was made to apply aspiration
thrombectomy using a penumbra device-CAT 8.

Post aspiration thrombectomy venography demonstrated improved patency of the
main portal vein on post venography with minimal flow through the TIPS.  The
diagnostic venography was medically necessary given the absence of recent
catheter venography. TPA was administered into the TIPS stent via the TIPS
sheath.  However, the TIPS itself remained potentially thrombosed.  It was
therefore decided to leave a ___ thrombolysis infusion
catheter in place overnight for tPA administration.
The sheath was then secured to the skin at the right neck site using an 0 silk
suture.  The infusion catheter was secured to the outer sheath.  A sterile
dressing was applied.
The percutaneous transhepatic access was embolized using Gelfoam pledgets.  A
sterile dressing was applied. Limited US did not demonstrate any ___
fluid post tract embolization.
Next, the right arm was prepped and draped in the usual sterile fashion.
Under ultrasound guidance, the patent basilic vein was accessed.  A
double-lumen PICC was inserted with the tip of the PICC in the SVC.  The line
was flushed, secured to the skin and a sterile dressing was applied.

The patient tolerated the procedure well.  There were no immediate
post-procedure complications. The patient was transferred to the ICU in stable
condition.

FINDINGS:


1. Pre-TIPS right atrial pressure of 20 mmHg.
2. Occluded indwelling TIPS with inability to get access via transjugular
approach initially
3. Successful percutaneous access the occluded TIPS using a 20 gauge Chiba
needle.  An 018 wire was then snared superiorly through the right IJ approach
sheath
4. Direct TIPS access venography demonstrated significant clot burden within
the main portal vein.
5. Cone beam CT demonstrated occluded TIPS with passage of access wires within
the stent without evidence for crossing interstices of the portal end of the
TIPS.
6. Post new TIPS extension right atrial pressure of 20 and portal pressure of
45 resulting in portosystemic gradient of 25 mmHg.
7. Successful balloon angioplasty of the main portal vein.  Angioplasty of the
indwelling TIPS and TIPS was also performed up to 10 mm.
8.
9. Post plasty venography demonstrated large decompressive left upper quadrant
gastric varices and other upper abdominal collateral venous channels.  There
was significant thrombosis of the main portal vein.
10. Post plasty venography demonstrated significant clot burden within the
main portal vein and TIPS.  Aspiration thrombectomy of the main portal vein
and TIPS was performed using the penumbra aspiration device with significant
debulking of clot post aspiration thrombectomy.
 11. Post plasty cone beam CT demonstrated an irregular narrowing at the
cranial portion of the new portosystemic shunt.  This was successfully lined
using an  uncovered 12 x 40 x 75 luminnex stent
___. Post plasty and application of the aspiration catheter venography
demonstrated patent main portal vein.  The TIPS was occluded at the end of the
procedure.
13. A 4 ___ ___ lysis catheter was placed in main portal vein
for tPA infusion
14. Gel-Foam pledget tract embolization of the percutaneous transhepatic TIPS
access.  Post tract embolization focused ultrasound demonstrated no evidence
of local hematoma.
15. A double-lumen PICC was placed via patent right basilic vein with tip in
the distal SVC.

IMPRESSION:

Successful right internal jugular access with direct transjugular intrahepatic
portosystemic shunt revision with extension of the TIPS cranially.

New direct TIPS aspiration thrombectomy.

Thrombolysis catheter placement through the right IJ sheath for overnight
thrombolysis


Insurance policy: CT Maxillofacial without contrast (CPT® 70486) or CT Sinus, limited without contrast
(CPT® 76380) is indicated in those with suspicion of Upper Airway Cough Syndrome
(UACS) in the following:4,5,6
o Clinical criteria for chronic rhinosinusitis (CRS) or acute/recurrent rhinosinusitis
are met, as per Sinus and Facial Imaging (HD 29.1) ; OR ALL of the following:
 At least a one week trial of daily antihistamine/decongestant
 Initial evaluation with a chest x-ray and/or CT Chest after the current episode
of cough started or changed
 All medications known to cause cough have been discontinued
Question: Is this service considered medically necessary for the patient? If not, what additional information could be included for the service to be considered medically necessary?
'''

# Tokenize the input text with truncation
inputs = tokenizer(text, return_tensors="pt", truncation=True, max_length=512)

# Generate text
generated_ids = model.generate(
    inputs["input_ids"],
    max_new_tokens=50,  # Specify the number of new tokens to generate
    num_beams=5,  # Beam search for better quality text
    no_repeat_ngram_size=2,  # Prevent repetition
    early_stopping=True  # Stop when the model is confident
)

# Decode the generated text
generated_text = tokenizer.decode(generated_ids[0], skip_special_tokens=True)

print(f"Generated text: {generated_text}")

# %% [markdown]
# ##Bloom: WORKING BUT NOT USEFUL RESPONSE

# %%
# Load model directly
from transformers import AutoTokenizer, AutoModelForCausalLM
import torch

tokenizer = AutoTokenizer.from_pretrained("bigscience/bloom-560m")
model = AutoModelForCausalLM.from_pretrained("bigscience/bloom-560m")
# Out:
# tokenizer_config.json:   0%|          | 0.00/222 [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/14.5M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/85.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/693 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/1.12G [00:00<?, ?B/s]

# %%
text = '''
Patient notes: INDICATION:  ___ year old man with congenital hepatic fibrosis and portal
hypertension  // TIPS revision/thrombectomy - seen by Dr. ___ ___

COMPARISON:  CT of the abdomen pelvis dated ___

TECHNIQUE:  OPERATORS: Dr. ___ Dr. ___ Interventional
___ and Dr. ___ fellow performed the
procedure.  The attending(s) personally supervised the trainee during any key
components of the procedure where applicable and reviewed and agrees with the
findings as reported below.
ANESTHESIA: Moderate sedation was provided by administrating divided doses of
300mcg of fentanyl and 7.5 mg of midazolam throughout the total intra-service
time of 7 hours and 58 minutes during which the patient's hemodynamic
parameters were continuously monitored by an independent trained radiology
nurse.  1% lidocaine was injected in the skin and subcutaneous tissues
overlying the access site.
MEDICATIONS: 4 mg intravenous tPA delivered through TIPS sheath
CONTRAST: 235 ml of Optiray contrast
FLUOROSCOPY TIME AND DOSE:  184.6 minutes, 2710 mGy

PROCEDURE:
1. Right internal jugular venous access using ultrasound.
2. Pre-procedure right atrial pressure measurements
3. Percutaneous transhepatic access into the TIPS stent.
4. Retrograde snaring of the percutaneous access into the right IJ
5. Trans jugular approach direct access into the upper portion of the
pre-existing TIPS stent
6. Cone beam CT of the TIPS and portal venous system prior to placement of the
new direct TIPS into the pre-existing TIPS
7. Placement of a 10 mm x 6 cm + 2 cm Viatorr partially-covered stent
8. Post-stenting balloon angioplasty of the TIPS shunt and portal vein with a
10 mm balloon.
9. Post-stenting portal venograms.
10. Extension of the cranial portion of the new portosystemic shunt (DIPS)
using a 12 x 40 x 75 lumenneX stent
___. Aspiration thrombectomy of the main portal vein and TIPS stent using a
penumbra device- CAT 8 system
12. TPA administration via the TIPS sheath
13. Gel-Foam pledget tract embolization of the percutaneous transhepatic TIPS
access
14. Placement of a tPA infusion catheter into the portal vein/SMV for
resistant clot
15. A double-lumen PICC was placed via patent right basilic vein


PROCEDURE DETAILS: Following the discussion of the risks, benefits and
alternatives to the procedure, written informed consent was obtained from the
patient. The patient was then brought to the angiography suite and placed
supine on the exam table. A pre-procedure time-out was performed per ___
protocol.  The right neck and abdomen were prepped and draped in the usual
sterile fashion.

Under continuous ultrasound guidance, the patent right internal jugular vein
was compressible and accessed using a micropuncture needle.  Images of
ultrasound access were stored on PACS. Subsequently a Nitinol wire was passed
into the right atrium using fluoroscopic guidance. A small incision was made
at the needle entry site. The needle was exchanged for a micropuncture sheath.
The Nitinol wire was removed and a ___ wire was advanced distally into
the IVC.

The micropuncture sheath was then removed and a 10 ___ sheath was advanced
over the wire into the inferior vena cava.  Right atrium pressure measurements
were obtained.  Multiple 5 ___ catheters including an MPA, SOS, C2 modified
___ catheters were used to attempt access into the existing TIPS.  These were
unsuccessful initially.  Access into the existing TIPS was then obtained using
a TIPS set.  The TIPS cannula device was inserted over the Amplatz wire and
the wire was exchanged for a long Chiba needle. The needle was then advanced
through liver parenchyma.  Upon access into the existing TIPS, a J-tip wire
was introduced into the catheter to pass into the portal vein via the TIPS,
with care taken not to traverse the interstices of the portal end of the TIPS.
A straight flush catheter was advanced over the wire and a contrast enhanced
portal venogram was performed.  Once access had been achieved into the TIPS,
the direct TIPS tract was angioplasties up to 10 mm.

Percutaneous transhepatic TIPS access was achieved into the mid portion of the
TIPS using a 20 gauge Chiba needle.  Stiff 018 v 18 wire was then advanced
into the existing TIPS.  This was snared through the direct right IJV approach
TIPS access sheath into the right IJ for through and through access.  Once
access was established into the portal system, this was converted into an 035
system using several exchanges involving Rubicon catheters and multiple 035
wires including stiff glide, glide and Amplatz wires.

Attempts at retrograde wire access to the cranial portion of the occluded TIPS
via the percutaneous transhepatic access were unsuccessful after multiple
attempts.  A cone beam CT was then performed.
 Rotational cone-beam CT angiography was performed to help delineate the
anatomy.  Multiplanar CT images were reconstructed and 3D volume-rendered
images of the venous anatomy required post-processing on an independent
workstation under direct physician ___.  These images were used in the
interpretation, decision making for intervention and reporting of this
procedure.
Next, through the new tranjugular direct TIPS access, the TIPS itself and the
main portal vein were treated with 10mm plasty using high-pressure balloons.
Post plasty venography was performed which demonstrated clot burden in the
main portal vein in TIPS with little flow through the TIPS itself.  Further
balloon plasty was performed at several locations, as documented.  Once
appropriate opacification of the main portal vein was confirmed, a new  10 x 6
+ 2 cm Viatorr partially-covered stent was advanced into appropriate position
and deployed. Following stent deployment, the stent was dilated using a 10 mm
balloon.

Post stenting venography demonstrated significant clot burden and irregular
appearance of the superior portion of the stent.  Another cone beam CT was
therefore performed to delineate anatomy and interventional planning.

Rotational cone-beam CT angiography was performed to help delineate the
anatomy.  Multiplanar CT images were reconstructed and 3D volume-rendered
images of the venous anatomy required post-processing on an independent
workstation under direct physician ___.  These images were used in the
interpretation, decision making for intervention and reporting of this
procedure.
A decision was made to line the cranial aspect of the new direct TIPS with and
uncovered 12 x 40 x 75 luminnex stent.  This was deployed in the appropriate
position with care being taken to avoid stent migration.  Post repeat stenting
balloon plasty was performed up to 12 mm.  This included portions of the
direct TIPS, the pre-existing TIPS as well as the main portal vein.  Post
plasty injections demonstrated still significant clot burden within the main
portal vein and tributaries.  A decision was made to apply aspiration
thrombectomy using a penumbra device-CAT 8.

Post aspiration thrombectomy venography demonstrated improved patency of the
main portal vein on post venography with minimal flow through the TIPS.  The
diagnostic venography was medically necessary given the absence of recent
catheter venography. TPA was administered into the TIPS stent via the TIPS
sheath.  However, the TIPS itself remained potentially thrombosed.  It was
therefore decided to leave a ___ thrombolysis infusion
catheter in place overnight for tPA administration.
The sheath was then secured to the skin at the right neck site using an 0 silk
suture.  The infusion catheter was secured to the outer sheath.  A sterile
dressing was applied.
The percutaneous transhepatic access was embolized using Gelfoam pledgets.  A
sterile dressing was applied. Limited US did not demonstrate any ___
fluid post tract embolization.
Next, the right arm was prepped and draped in the usual sterile fashion.
Under ultrasound guidance, the patent basilic vein was accessed.  A
double-lumen PICC was inserted with the tip of the PICC in the SVC.  The line
was flushed, secured to the skin and a sterile dressing was applied.

The patient tolerated the procedure well.  There were no immediate
post-procedure complications. The patient was transferred to the ICU in stable
condition.

FINDINGS:


1. Pre-TIPS right atrial pressure of 20 mmHg.
2. Occluded indwelling TIPS with inability to get access via transjugular
approach initially
3. Successful percutaneous access the occluded TIPS using a 20 gauge Chiba
needle.  An 018 wire was then snared superiorly through the right IJ approach
sheath
4. Direct TIPS access venography demonstrated significant clot burden within
the main portal vein.
5. Cone beam CT demonstrated occluded TIPS with passage of access wires within
the stent without evidence for crossing interstices of the portal end of the
TIPS.
6. Post new TIPS extension right atrial pressure of 20 and portal pressure of
45 resulting in portosystemic gradient of 25 mmHg.
7. Successful balloon angioplasty of the main portal vein.  Angioplasty of the
indwelling TIPS and TIPS was also performed up to 10 mm.
8.
9. Post plasty venography demonstrated large decompressive left upper quadrant
gastric varices and other upper abdominal collateral venous channels.  There
was significant thrombosis of the main portal vein.
10. Post plasty venography demonstrated significant clot burden within the
main portal vein and TIPS.  Aspiration thrombectomy of the main portal vein
and TIPS was performed using the penumbra aspiration device with significant
debulking of clot post aspiration thrombectomy.
 11. Post plasty cone beam CT demonstrated an irregular narrowing at the
cranial portion of the new portosystemic shunt.  This was successfully lined
using an  uncovered 12 x 40 x 75 luminnex stent
___. Post plasty and application of the aspiration catheter venography
demonstrated patent main portal vein.  The TIPS was occluded at the end of the
procedure.
13. A 4 ___ ___ lysis catheter was placed in main portal vein
for tPA infusion
14. Gel-Foam pledget tract embolization of the percutaneous transhepatic TIPS
access.  Post tract embolization focused ultrasound demonstrated no evidence
of local hematoma.
15. A double-lumen PICC was placed via patent right basilic vein with tip in
the distal SVC.

IMPRESSION:

Successful right internal jugular access with direct transjugular intrahepatic
portosystemic shunt revision with extension of the TIPS cranially.

New direct TIPS aspiration thrombectomy.

Thrombolysis catheter placement through the right IJ sheath for overnight
thrombolysis


Insurance policy: CT Maxillofacial without contrast (CPT® 70486) or CT Sinus, limited without contrast
(CPT® 76380) is indicated in those with suspicion of Upper Airway Cough Syndrome
(UACS) in the following:4,5,6
o Clinical criteria for chronic rhinosinusitis (CRS) or acute/recurrent rhinosinusitis
are met, as per Sinus and Facial Imaging (HD 29.1) ; OR ALL of the following:
 At least a one week trial of daily antihistamine/decongestant
 Initial evaluation with a chest x-ray and/or CT Chest after the current episode
of cough started or changed
 All medications known to cause cough have been discontinued

Question: Is this service considered medically necessary for the patient? If not, what additional information could be included for the service to be considered medically necessary?
'''

# Tokenize the input text
inputs = tokenizer(text, return_tensors="pt", truncation=True, max_length=512)

# Generate text
# Set parameters for generation
generated_ids = model.generate(
    inputs["input_ids"],
    max_new_tokens=50,  # Specify the number of new tokens to generate
    num_beams=5,  # Beam search for better quality text
    no_repeat_ngram_size=2,  # Prevent repetition
    early_stopping=True  # Stop when the model is confident
)

# Decode the generated text
generated_text = tokenizer.decode(generated_ids[0], skip_special_tokens=True)

print(f"Generated text: {generated_text}")
# Out:
# Generated text: Patient notes: INDICATION:  ___ year old man with congenital hepatic fibrosis and portal
# hypertension  // TIPS revision/thrombectomy - seen by Dr. ___ ___
#
# COMPARISON:  CT of the abdomen pelvis dated ___
#
# TECHNIQUE:  OPERATORS: Dr. ___ Dr. ___ Interventional
# ___ and Dr. ___ fellow performed the
# procedure.  The attending(s) personally supervised the trainee during any key
# components of the procedure where applicable and reviewed and agrees with the
# findings as reported below.
# ANESTHESIA: Moderate sedation was provided by administrating divided doses of
# 300mcg of fentanyl and 7.5 mg of midazolam throughout the total intra-service
# time of 7 hours and 58 minutes during which the patient's hemodynamic
# parameters were continuously monitored by an independent trained radiology
# nurse.  1% lidocaine was injected in the skin and subcutaneous tissues
# overlying the access site.
# MEDICATIONS: 4 mg intravenous tPA delivered through TIPS sheath
# ...

# %% [markdown]
# ## Medical-Llama 3: RAM CRASHED

# %%
# Load model directly
from transformers import AutoTokenizer, AutoModelForCausalLM

tokenizer = AutoTokenizer.from_pretrained("ruslanmv/Medical-Llama3-8B")
model = AutoModelForCausalLM.from_pretrained("ruslanmv/Medical-Llama3-8B")

input_text = """
Patient notes: INDICATION:  ___ year old man with congenital hepatic fibrosis and portal
hypertension  // TIPS revision/thrombectomy - seen by Dr. ___ ___

COMPARISON:  CT of the abdomen pelvis dated ___

TECHNIQUE:  OPERATORS: Dr. ___ Dr. ___ Interventional
___ and Dr. ___ fellow performed the
procedure.  The attending(s) personally supervised the trainee during any key
components of the procedure where applicable and reviewed and agrees with the
findings as reported below.
ANESTHESIA: Moderate sedation was provided by administrating divided doses of
300mcg of fentanyl and 7.5 mg of midazolam throughout the total intra-service
time of 7 hours and 58 minutes during which the patient's hemodynamic
parameters were continuously monitored by an independent trained radiology
nurse.  1% lidocaine was injected in the skin and subcutaneous tissues
overlying the access site.
MEDICATIONS: 4 mg intravenous tPA delivered through TIPS sheath
CONTRAST: 235 ml of Optiray contrast
FLUOROSCOPY TIME AND DOSE:  184.6 minutes, 2710 mGy

PROCEDURE:
1. Right internal jugular venous access using ultrasound.
2. Pre-procedure right atrial pressure measurements
3. Percutaneous transhepatic access into the TIPS stent.
4. Retrograde snaring of the percutaneous access into the right IJ
5. Trans jugular approach direct access into the upper portion of the
pre-existing TIPS stent
6. Cone beam CT of the TIPS and portal venous system prior to placement of the
new direct TIPS into the pre-existing TIPS
7. Placement of a 10 mm x 6 cm + 2 cm Viatorr partially-covered stent
8. Post-stenting balloon angioplasty of the TIPS shunt and portal vein with a
10 mm balloon.
9. Post-stenting portal venograms.
10. Extension of the cranial portion of the new portosystemic shunt (DIPS)
using a 12 x 40 x 75 lumenneX stent
___. Aspiration thrombectomy of the main portal vein and TIPS stent using a
penumbra device- CAT 8 system
12. TPA administration via the TIPS sheath
13. Gel-Foam pledget tract embolization of the percutaneous transhepatic TIPS
access
14. Placement of a tPA infusion catheter into the portal vein/SMV for
resistant clot
15. A double-lumen PICC was placed via patent right basilic vein


PROCEDURE DETAILS: Following the discussion of the risks, benefits and
alternatives to the procedure, written informed consent was obtained from the
patient. The patient was then brought to the angiography suite and placed
supine on the exam table. A pre-procedure time-out was performed per ___
protocol.  The right neck and abdomen were prepped and draped in the usual
sterile fashion.

Under continuous ultrasound guidance, the patent right internal jugular vein
was compressible and accessed using a micropuncture needle.  Images of
ultrasound access were stored on PACS. Subsequently a Nitinol wire was passed
into the right atrium using fluoroscopic guidance. A small incision was made
at the needle entry site. The needle was exchanged for a micropuncture sheath.
The Nitinol wire was removed and a ___ wire was advanced distally into
the IVC.

The micropuncture sheath was then removed and a 10 ___ sheath was advanced
over the wire into the inferior vena cava.  Right atrium pressure measurements
were obtained.  Multiple 5 ___ catheters including an MPA, SOS, C2 modified
___ catheters were used to attempt access into the existing TIPS.  These were
unsuccessful initially.  Access into the existing TIPS was then obtained using
a TIPS set.  The TIPS cannula device was inserted over the Amplatz wire and
the wire was exchanged for a long Chiba needle. The needle was then advanced
through liver parenchyma.  Upon access into the existing TIPS, a J-tip wire
was introduced into the catheter to pass into the portal vein via the TIPS,
with care taken not to traverse the interstices of the portal end of the TIPS.
A straight flush catheter was advanced over the wire and a contrast enhanced
portal venogram was performed.  Once access had been achieved into the TIPS,
the direct TIPS tract was angioplasties up to 10 mm.

Percutaneous transhepatic TIPS access was achieved into the mid portion of the
TIPS using a 20 gauge Chiba needle.  Stiff 018 v 18 wire was then advanced
into the existing TIPS.  This was snared through the direct right IJV approach
TIPS access sheath into the right IJ for through and through access.  Once
access was established into the portal system, this was converted into an 035
system using several exchanges involving Rubicon catheters and multiple 035
wires including stiff glide, glide and Amplatz wires.

Attempts at retrograde wire access to the cranial portion of the occluded TIPS
via the percutaneous transhepatic access were unsuccessful after multiple
attempts.  A cone beam CT was then performed.
 Rotational cone-beam CT angiography was performed to help delineate the
anatomy.  Multiplanar CT images were reconstructed and 3D volume-rendered
images of the venous anatomy required post-processing on an independent
workstation under direct physician ___.  These images were used in the
interpretation, decision making for intervention and reporting of this
procedure.
Next, through the new tranjugular direct TIPS access, the TIPS itself and the
main portal vein were treated with 10mm plasty using high-pressure balloons.
Post plasty venography was performed which demonstrated clot burden in the
main portal vein in TIPS with little flow through the TIPS itself.  Further
balloon plasty was performed at several locations, as documented.  Once
appropriate opacification of the main portal vein was confirmed, a new  10 x 6
+ 2 cm Viatorr partially-covered stent was advanced into appropriate position
and deployed. Following stent deployment, the stent was dilated using a 10 mm
balloon.

Post stenting venography demonstrated significant clot burden and irregular
appearance of the superior portion of the stent.  Another cone beam CT was
therefore performed to delineate anatomy and interventional planning.

Rotational cone-beam CT angiography was performed to help delineate the
anatomy.  Multiplanar CT images were reconstructed and 3D volume-rendered
images of the venous anatomy required post-processing on an independent
workstation under direct physician ___.  These images were used in the
interpretation, decision making for intervention and reporting of this
procedure.
A decision was made to line the cranial aspect of the new direct TIPS with and
uncovered 12 x 40 x 75 luminnex stent.  This was deployed in the appropriate
position with care being taken to avoid stent migration.  Post repeat stenting
balloon plasty was performed up to 12 mm.  This included portions of the
direct TIPS, the pre-existing TIPS as well as the main portal vein.  Post
plasty injections demonstrated still significant clot burden within the main
portal vein and tributaries.  A decision was made to apply aspiration
thrombectomy using a penumbra device-CAT 8.

Post aspiration thrombectomy venography demonstrated improved patency of the
main portal vein on post venography with minimal flow through the TIPS.  The
diagnostic venography was medically necessary given the absence of recent
catheter venography. TPA was administered into the TIPS stent via the TIPS
sheath.  However, the TIPS itself remained potentially thrombosed.  It was
therefore decided to leave a ___ thrombolysis infusion
catheter in place overnight for tPA administration.
The sheath was then secured to the skin at the right neck site using an 0 silk
suture.  The infusion catheter was secured to the outer sheath.  A sterile
dressing was applied.
The percutaneous transhepatic access was embolized using Gelfoam pledgets.  A
sterile dressing was applied. Limited US did not demonstrate any ___
fluid post tract embolization.
Next, the right arm was prepped and draped in the usual sterile fashion.
Under ultrasound guidance, the patent basilic vein was accessed.  A
double-lumen PICC was inserted with the tip of the PICC in the SVC.  The line
was flushed, secured to the skin and a sterile dressing was applied.

The patient tolerated the procedure well.  There were no immediate
post-procedure complications. The patient was transferred to the ICU in stable
condition.

FINDINGS:


1. Pre-TIPS right atrial pressure of 20 mmHg.
2. Occluded indwelling TIPS with inability to get access via transjugular
approach initially
3. Successful percutaneous access the occluded TIPS using a 20 gauge Chiba
needle.  An 018 wire was then snared superiorly through the right IJ approach
sheath
4. Direct TIPS access venography demonstrated significant clot burden within
the main portal vein.
5. Cone beam CT demonstrated occluded TIPS with passage of access wires within
the stent without evidence for crossing interstices of the portal end of the
TIPS.
6. Post new TIPS extension right atrial pressure of 20 and portal pressure of
45 resulting in portosystemic gradient of 25 mmHg.
7. Successful balloon angioplasty of the main portal vein.  Angioplasty of the
indwelling TIPS and TIPS was also performed up to 10 mm.
8.
9. Post plasty venography demonstrated large decompressive left upper quadrant
gastric varices and other upper abdominal collateral venous channels.  There
was significant thrombosis of the main portal vein.
10. Post plasty venography demonstrated significant clot burden within the
main portal vein and TIPS.  Aspiration thrombectomy of the main portal vein
and TIPS was performed using the penumbra aspiration device with significant
debulking of clot post aspiration thrombectomy.
 11. Post plasty cone beam CT demonstrated an irregular narrowing at the
cranial portion of the new portosystemic shunt.  This was successfully lined
using an  uncovered 12 x 40 x 75 luminnex stent
___. Post plasty and application of the aspiration catheter venography
demonstrated patent main portal vein.  The TIPS was occluded at the end of the
procedure.
13. A 4 ___ ___ lysis catheter was placed in main portal vein
for tPA infusion
14. Gel-Foam pledget tract embolization of the percutaneous transhepatic TIPS
access.  Post tract embolization focused ultrasound demonstrated no evidence
of local hematoma.
15. A double-lumen PICC was placed via patent right basilic vein with tip in
the distal SVC.

IMPRESSION:

Successful right internal jugular access with direct transjugular intrahepatic
portosystemic shunt revision with extension of the TIPS cranially.

New direct TIPS aspiration thrombectomy.

Thrombolysis catheter placement through the right IJ sheath for overnight
thrombolysis


Insurance policy: CT Maxillofacial without contrast (CPT® 70486) or CT Sinus, limited without contrast
(CPT® 76380) is indicated in those with suspicion of Upper Airway Cough Syndrome
(UACS) in the following:4,5,6
o Clinical criteria for chronic rhinosinusitis (CRS) or acute/recurrent rhinosinusitis
are met, as per Sinus and Facial Imaging (HD 29.1) ; OR ALL of the following:
 At least a one week trial of daily antihistamine/decongestant
 Initial evaluation with a chest x-ray and/or CT Chest after the current episode
of cough started or changed
 All medications known to cause cough have been discontinued
Question: Is this service considered medically necessary for the patient? If not, what additional information could be included for the service to be considered medically necessary?
"""
input = tokenizer(input_text, truncation=True, padding=True, return_tensors="pt")

# Generate text based on the prompt
output = model.generate(input_ids=input['input_ids'], max_length=30000, num_return_sequences=1, early_stopping=True)

generated_text = tokenizer.decode(output[0], skip_special_tokens=True)
print(generated_text)


# result = generator(input_text, max_length=1000, num_return_sequences=1)

# print(result[0]['generated_text'])
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:89: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
